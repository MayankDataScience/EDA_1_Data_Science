# %% [markdown]
# <a href="https://colab.research.google.com/github/MayankDataScience/EDA_1_Data_Science/blob/main/Play_store_app_review_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Play store app review analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Team
# ##### **Team Member 1 -**Mayank Gudadhe
# ##### **Team Member 2 -**Vishal Singh Sangral
# ##### **Team Member 3 -**Kiran Mundhe
# ##### **Team Member 4 -**Amiya Palai
# ##### **Team Member 5 -**Nipu Mishra

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here:-
# https://github.com/MayankDataScience/EDA_1_Data_Science

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# Our **Lucifer** Group making an EDA project on Play store app review to discover key factors responsible for app engagement and success. We are using two datasets one is Play Store Data.csv and another is User Reviews.csv.
#
# We will extract insights from this Data Set which will help in becoming a best app.
#
# Some of the insights are ⬇
#
#
#
# 1.  Top 5 Apps and their Rating.
# 1.  Top Apps are Paid or Free.
# 3.  Top 10 Apps Category.
# 4.  Category which has highest number of installation.
# 5.  When app is paid then how much it affects the rating.
# 6.Ratings and reviews are corelated ?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here:-
#
# Our Business objective is to discover all this factors who is responsible for app success and after reviewing all the fators.we are extracting insights which will help us to creating a positive business impact.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# We are importing an Libraries numpy for working with arrays.
# We are using pandas for data visualization and analyzing the data. 
# Then we using matplotlib and seaborn for graphical representation of data.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Path of Folder where our CSV files
path1='/content/drive/MyDrive/Almabetter Data science/EDA_Projects'

# %%
# we are retriving data from the Dataframe using  read_csv() .
df1=pd.read_csv(path1 + '/Play Store Data.csv')
df2=pd.read_csv(path1 + '/User Reviews.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df1.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
# 5     167  5.6M      50,000+  Free     0       Everyone
# 6     178   19M      50,000+  Free     0       Everyone
# 7   36815   29M   1,000,000+  Free     0       Everyone
# 8   13791   33M   1,000,000+  Free     0       Everyone
# 9     121  3.1M      10,000+  Free     0       Everyone
#
#                       Genres        Last Updated         Current Ver  \
# 0               Art & Design     January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play    January 15, 2018               2.0.0
# 2               Art & Design      August 1, 2018               1.2.4
# 3               Art & Design        June 8, 2018  Varies with device
# 4    Art & Design;Creativity       June 20, 2018                 1.1
# 5               Art & Design      March 26, 2017                 1.0
# 6               Art & Design      April 26, 2018                 1.1
# 7               Art & Design       June 14, 2018            6.1.61.1
# 8               Art & Design  September 20, 2017               2.9.2
# 9    Art & Design;Creativity        July 3, 2018                 2.8
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up
# 5    2.3 and up
# 6  4.0.3 and up
# 7    4.2 and up
# 8    3.0 and up
# 9  4.0.3 and up

# %%
df2.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print('Total Number of rows in Play Store Data.csv :-',len(df1))
print('Total Number of Columns in Play Store Data.csv :-',len(df1.columns))

print('Total Number of rows in User Reviews.csv :-',len(df2))
print('Total Number of Columns in User Reviews.csv :-',len(df2.columns))
# Out:
# Total Number of rows in Play Store Data.csv :- 10841
# Total Number of Columns in Play Store Data.csv :- 13
# Total Number of rows in User Reviews.csv :- 64295
# Total Number of Columns in User Reviews.csv :- 5

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df1[df1.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
#        Reviews                Size      Installs  Type Price Content Rating  \
# 229      80805  Varies with device    5,000,000+  Free     0       Everyone
# 236     159872  Varies with device   10,000,000+  Free     0       Everyone
# 239      70991  Varies with device    5,000,000+  Free     0       Everyone
# 256      31614                 37M   10,000,000+  Free     0       Everyone
# 261       6989  Varies with device    1,000,000+  Free     0       Everyone
# ...        ...                 ...           ...   ...   ...            ...
# 8643    404610  Varies with device   10,000,000+  Free     0       Everyone
# 8654     25370  Varies with device    1,000,000+  Free     0       Everyone
# 8658   2401017  Varies with device  100,000,000+  Free     0       Everyone
# 10049      123                 86M       10,000+  Free     0       Everyone
# 10768       63                 24M       10,000+  Free     0       Everyone
#
#              Genres       Last Updated         Current Ver         Android Ver
# 229        Business  February 26, 2018  Varies with device        4.0.3 and up
# 236        Business      July 31, 2018  Varies with device  Varies with device
# 239        Business      July 24, 2018    2.19.0.204537701          4.4 and up
# 256        Business      July 20, 2018      4.1.28165.0716          4.0 and up
# 261        Business      July 16, 2018           4.3.0.508          4.4 and up
# ...             ...                ...                 ...                 ...
# 8643   Productivity      April 6, 2018  Varies with device  Varies with device
# 8654   Productivity     August 6, 2018  Varies with device  Varies with device
# 8658   Productivity      June 27, 2018  Varies with device  Varies with device
# 10049       Medical       June 1, 2018              0.6.88          5.0 and up
# 10768       Medical      June 22, 2018               2.3.1          5.0 and up
#
# [483 rows x 13 columns]

# %%
# we saw that after droping duplicates rows comes to 10358 
df1.drop_duplicates()
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10358 rows x 13 columns]

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df1.isnull().sum()
#df1.notnull()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df1[df1['Rating'].isna()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# 23         61  7.0M  100,000+  Free     0       Everyone
# 113       182  5.7M  100,000+  Free     0   Everyone 10+
# 123       119  3.7M   50,000+  Free     0       Everyone
# 126       654  7.4M  100,000+  Free     0           Teen
# 129        77  2.9M   10,000+  Free     0     Mature 17+
# ...       ...   ...       ...   ...   ...            ...
# 10824      67   82M   10,000+  Free     0       Everyone
# 10825       7  7.7M      100+  Free     0           Teen
# 10831      38  9.8M    5,000+  Free     0       Everyone
# 10835       0  9.6M       10+  Free     0       Everyone
# 10838       3  9.5M    1,000+  Free     0       Everyone
#
#                                 Genres        Last Updated Current Ver  \
# 23     Art & Design;Action & Adventure       March 7, 2018       1.0.0
# 113                             Beauty  September 20, 2017         8.0
# 123                             Beauty       July 23, 2018         1.3
# 126                             Beauty       July 17, 2018        1.15
# 129                             Beauty      August 8, 2017         2.0
# ...                                ...                 ...         ...
# 10824                          Medical       July 31, 2018       2.2.2
# 10825                           Social    February 2, 2018         1.0
# 10831                Maps & Navigation       June 13, 2018   2.0.148.0
# 10835                         Business  September 29, 2016       1.1.5
# 10838                          Medical    January 20, 2017         1.0
#
#       Android Ver
# 23     4.1 and up
# 113    3.0 and up
# 123    4.1 and up
# 126    4.1 and up
# 129    2.3 and up
# ...           ...
# 10824  4.4 and up
# 10825  4.0 and up
# 10831  4.0 and up
# 10835  4.0 and up
# 10838  2.2 and up
#
# [1474 rows x 13 columns]

# %%
df1[df1['Type'].isna()]
# Out:
#                             App Category  Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
df1[df1['Android Ver'].isna()]
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#       Reviews    Size Installs  Type     Price Content Rating  \
# 4453      230     11M   1,000+  Paid     $1.49       Everyone
# 4490      189    2.1M  10,000+  Free         0       Everyone
# 10472    3.0M  1,000+     Free     0  Everyone            NaN
#
#                   Genres    Last Updated Current Ver Android Ver
# 4453     Personalization   July 20, 2018         4.4         NaN
# 4490     Personalization  March 27, 2018         1.1         NaN
# 10472  February 11, 2018          1.0.19  4.0 and up         NaN

# %%
df1[df1['Content Rating'].isna()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# Visualizing the missing values
# We Visualizing the missing values for Play Store Data.csv 
plt.figure(figsize=(16,6))
plt.bar(list(df1.columns),list(df1.isnull().sum()),color='red')
plt.xlabel('Columns')
plt.ylabel('Null Value')
plt.title('Visualization of Null/Missing value')
plt.show()

# %%
# We Visualizing the missing values for User Reviews.csv 
plt.figure(figsize=(16,6))
plt.bar(list(df2.columns),list(df2.isnull().sum()),color='brown')
plt.xlabel('Columns')
plt.ylabel('Null Value')
plt.title('Visualization of Null/Missing value')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here
#
# We understand about this dataset is :-
#
# 1.In df1 which is Play Store Data.csv has 10841 entries, 0 to 10840
# Data columns has total 13 columns.
#
# 2.In df2 which is User Reviews.csv  has 64295 entries, 0 to 64294
# Data columns has total 5 columns.
#
# 3.In our df1 dataset we analize that

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe
df1.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df2.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df1.loc[:].nunique()
# Out:
# App               9660
# Category            34
# Rating              40
# Reviews           6002
# Size               462
# Installs            22
# Type                 3
# Price               93
# Content Rating       6
# Genres             120
# Last Updated      1378
# Current Ver       2832
# Android Ver         33
# dtype: int64

# %%
df2.loc[:].nunique()
# Out:
# App                        1074
# Translated_Review         27994
# Sentiment                     3
# Sentiment_Polarity         5410
# Sentiment_Subjectivity     4474
# dtype: int64

# %% [markdown]
# We have to check unique values for each variable of df1

# %%
df1['App'].unique()
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook',
#        'Coloring book moana',
#        'U Launcher Lite – FREE Live Cool Themes, Hide Apps', ...,
#        'Parkinson Exercices FR', 'The SCP Foundation DB fr nn5n',
#        'iHoroscope - 2018 Daily Horoscope & Astrology'], dtype=object)

# %%
df1['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df1['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
df1['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
df1['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '1,000+',
#        '470k', '226k', '240k', '89k', '234k', '257k', '861k', '467k',
#        '157k', '44k', '676k', '67k', '552k', '885k', '1020k', '582k',
#        '619k'], dtype=object)

# %%
df1['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
df1['Type'].unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %%
df1['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', 'Everyone', '$1.20', '$1.04'], dtype=object)

# %%
df1['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated', nan], dtype=object)

# %%
df1['Genres'].unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
#        'Casual;Action & Adventure', 'Simulation', 'Adventure', 'Board',
#        'Trivia', 'Role Playing', 'Simulation;Education',
#        'Action;Action & Adventure', 'Casual;Brain Games',
#        'Simulation;Action & Adventure', 'Educational;Creativity',
#        'Puzzle;Brain Games', 'Educational;Education', 'Card;Brain Games',
#        'Educational;Brain Games', 'Educational;Pretend Play',
#        'Entertainment;Education', 'Casual;Education',
#        'Music;Music & Video', 'Racing;Action & Adventure',
#        'Arcade;Pretend Play', 'Role Playing;Action & Adventure',
#        'Simulation;Pretend Play', 'Puzzle;Creativity',
#        'Sports;Action & Adventure', 'Educational;Action & Adventure',
#        'Arcade;Action & Adventure', 'Entertainment;Action & Adventure',
#        'Puzzle;Action & Adventure', 'Strategy;Action & Adventure',
#        'Music & Audio;Music & Video', 'Health & Fitness;Education',
#        'Adventure;Education', 'Board;Brain Games',
#        'Board;Action & Adventure', 'Board;Pretend Play',
#        'Casual;Music & Video', 'Role Playing;Pretend Play',
#        'Entertainment;Pretend Play', 'Video Players & Editors;Creativity',
#        'Card;Action & Adventure', 'Medical', 'Social', 'Shopping',
#        'Photography', 'Travel & Local',
#        'Travel & Local;Action & Adventure', 'Tools', 'Tools;Education',
#        'Personalization', 'Productivity', 'Parenting',
#        'Parenting;Music & Video', 'Parenting;Education',
#        'Parenting;Brain Games', 'Weather', 'Video Players & Editors',
#        'Video Players & Editors;Music & Video', 'News & Magazines',
#        'Maps & Navigation', 'Health & Fitness;Action & Adventure',
#        'Educational', 'Casino', 'Adventure;Brain Games',
#        'Trivia;Education', 'Lifestyle;Education',
#        'Books & Reference;Creativity', 'Books & Reference;Education',
#        'Puzzle;Education', 'Role Playing;Education',
#        'Role Playing;Brain Games', 'Strategy;Education',
#        'Racing;Pretend Play', 'Communication;Creativity',
#        'February 11, 2018', 'Strategy;Creativity'], dtype=object)

# %%
df1['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
df1['Current Ver'].unique()
# Out:
# array(['1.0.0', '2.0.0', '1.2.4', ..., '1.0.612928', '0.3.4', '2.0.148.0'],
#       dtype=object)

# %%
df1['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %% [markdown]
# We have to check unique values of each variable for df2

# %%
df2['App'].unique()
# Out:
# array(['10 Best Foods for You', '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#        '11st', ..., 'Hotwire Hotel & Car Rental App',
#        'Housing-Real Estate & Property', 'Houzz Interior Design Ideas'],
#       dtype=object)

# %%
df2['Translated_Review'].unique()
# Out:
# array(['I like eat delicious food. That\'s I\'m cooking food myself, case "10 Best Foods" helps lot, also "Best Before (Shelf Life)"',
#        'This help eating healthy exercise regular basis', nan, ...,
#        'Dumb app, I wanted post property rent give option. Website work. Waste time space phone.',
#        'I property business got link SMS happy performance still guys need raise bar guys Cheers',
#        'Useless app, I searched flats kondapur, Hyderabad . None number reachable I know flats unavailable would keep posts active'],
#       dtype=object)

# %%
df2['Sentiment'].unique()
# Out:
# array(['Positive', nan, 'Neutral', 'Negative'], dtype=object)

# %%
df2['Sentiment_Polarity'].unique()
# Out:
# array([ 1.        ,  0.25      ,         nan, ..., -0.52857143,
#        -0.37777778,  0.17333333])

# %%
df2['Sentiment_Subjectivity'].unique()
# Out:
# array([0.53333333, 0.28846154,        nan, ..., 0.51145833, 0.7172619 ,
#        0.2594697 ])

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# First we make df1 to analysis ready
df1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df1[df1['Type'].isna()]
# Out:
#                             App Category  Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
df1.drop(9148,axis=0,inplace=True)

# %%
df1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1473
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df1.sample(50)
# Out:
#                                                    App             Category  \
# 393                                                Who        COMMUNICATION
# 5432                      Range Master: Sniper Academy               SPORTS
# 8218                                        DB Manager         PRODUCTIVITY
# 7507                      CL Pro Client for Craigslist             SHOPPING
# 4746                  X-VPN - Free Unlimited VPN Proxy                TOOLS
# 4518                ICQ — Video Calls & Chat Messenger        COMMUNICATION
# 8091                                          CY Konum      PERSONALIZATION
# 5510                                          AQ Coach               SPORTS
# 5048                               AppFinder by AppTap                TOOLS
# 3695                                         Play Tube        VIDEO_PLAYERS
# 8280                       Robin - DC Movie Collection               FAMILY
# 2841                     Photo Collage - Layout Editor          PHOTOGRAPHY
# 1442   Stop, Breathe & Think: Meditation & Mindfulness   HEALTH_AND_FITNESS
# 2908                                           Retrica          PHOTOGRAPHY
# 3863                        NAVITIME Bus Transit JAPAN  MAPS_AND_NAVIGATION
# 7609        Champions and Challengers - Adventure Time               FAMILY
# 13                               Mandala Coloring Book       ART_AND_DESIGN
# 4920                       AC Remote for LG - NOW FREE                TOOLS
# 638                          When Will You Get Married               DATING
# 1126                                      MetaTrader 4              FINANCE
# 2212                      Palace Pets in Whisker Haven               FAMILY
# 6882                    Maps & GPS Navigation — OsmAnd  MAPS_AND_NAVIGATION
# 10184              NCLEX-RN Q&A FLASH CARDS - FA Davis              MEDICAL
# 7825                                   Guide for CS:GO               FAMILY
# 4584   City Taxi Driver sim 2016: Cab simulator Game-s               FAMILY
# 1831                                  The Game of Life                 GAME
# 9275                                  EF Smart English               FAMILY
# 6841                               Bu Hangi Youtuber ?                 GAME
# 10827                               Fr Agnel Ambarnath               FAMILY
# 6711                        B. R. Ambedkar Jayanti SMS      PERSONALIZATION
# 3893                                        4 in a Row                 GAME
# 5882                             A-Z Screen Recorder -        VIDEO_PLAYERS
# 7245                                Overcomers CF - GA            LIFESTYLE
# 2312                                  Doctor On Demand              MEDICAL
# 9666                                      4Eternity EO             BUSINESS
# 3299                     Fraction Calculator Plus Free                TOOLS
# 3861                   Alopec - Online Shipping System  MAPS_AND_NAVIGATION
# 995                                     My Talking Pet        ENTERTAINMENT
# 242                                      Insightly CRM             BUSINESS
# 1211                                          OpenRice       FOOD_AND_DRINK
# 10230                   Download Facebook Photo Albums                TOOLS
# 4691                         San Andreas: Gang Crime V                 GAME
# 498              Free Dating App & Flirt Chat - Cheers               DATING
# 2104                     LEGO® Juniors Create & Cruise               FAMILY
# 7573               Ruler & Area Measurement (cm, inch)                TOOLS
# 4743                                        weather HD      PERSONALIZATION
# 9848                     Learn Italian with MosaLingua               FAMILY
# 7874                      CT Head Basic Interpretation               FAMILY
# 7587                       CN Sayin' - Cartoon Network               FAMILY
# 8075                                          WiFi FPV               FAMILY
#
#        Rating  Reviews                Size      Installs  Type  Price  \
# 393       4.3  2451093  Varies with device  100,000,000+  Free      0
# 5432      4.1    91935                 39M   10,000,000+  Free      0
# 8218      NaN        3                108k        1,000+  Free      0
# 7507      3.6       48                2.2M        5,000+  Free      0
# 4746      4.5    40617                 21M    5,000,000+  Free      0
# 4518      4.4   697939  Varies with device   10,000,000+  Free      0
# 8091      NaN        1                1.3M          100+  Free      0
# 5510      NaN        0                 28M            5+  Free      0
# 5048      2.0     2221                4.9M    5,000,000+  Free      0
# 3695      4.3    15874                5.4M    1,000,000+  Free      0
# 8280      NaN        1                2.3M          500+  Free      0
# 2841      4.5   285788                 46M   10,000,000+  Free      0
# 1442      4.3     8576  Varies with device    1,000,000+  Free      0
# 2908      4.3  6120977  Varies with device  100,000,000+  Free      0
# 3863      3.7     6939  Varies with device    1,000,000+  Free      0
# 7609      4.6    51973                 27M    1,000,000+  Free      0
# 13        4.6     4326                 21M      100,000+  Free      0
# 4920      3.7     1041                 28M      100,000+  Free      0
# 638       NaN        2                3.6M           10+  Free      0
# 1126      4.6   260547  Varies with device    5,000,000+  Free      0
# 2212      4.1    47213                 14M    5,000,000+  Free      0
# 6882      4.2    60820  Varies with device    5,000,000+  Free      0
# 10184     NaN        2                7.6M        1,000+  Free      0
# 7825      4.4    16459                 88M      500,000+  Free      0
# 4584      4.1    16111                 57M    1,000,000+  Free      0
# 1831      4.4    18621                 63M      100,000+  Paid  $2.99
# 9275      3.7      150                 11M        5,000+  Free      0
# 6841      NaN       31                 26M        1,000+  Free      0
# 10827     4.2      117                 13M        5,000+  Free      0
# 6711      NaN        0                3.0M          500+  Free      0
# 3893      3.8     4257  Varies with device      500,000+  Free      0
# 5882      NaN       17                3.7M          500+  Free      0
# 7245      5.0        7                 11M          100+  Free      0
# 2312      4.7    18674  Varies with device    1,000,000+  Free      0
# 9666      NaN        0                2.0M           10+  Free      0
# 3299      4.5   148506                 11M    5,000,000+  Free      0
# 3861      4.3     1240                 14M      100,000+  Free      0
# 995       4.6     6238  Varies with device      100,000+  Paid  $4.99
# 242       3.8     1383                 51M      100,000+  Free      0
# 1211      3.6    14952                 39M    1,000,000+  Free      0
# 10230     4.0     3840                2.5M      100,000+  Free      0
# 4691      4.1     2399                 42M      100,000+  Free      0
# 498       4.4      667                 27M       10,000+  Free      0
# 2104      4.1   673203                 73M   50,000,000+  Free      0
# 7573      4.3       10                8.2M       10,000+  Free      0
# 4743      4.0     1546                4.5M       10,000+  Paid  $1.99
# 9848      4.7     1719  Varies with device       50,000+  Paid  $4.99
# 7874      NaN        1                 16M          100+  Free      0
# 7587      4.5       85                 25M       10,000+  Free      0
# 8075      3.8      316                 19M      100,000+  Free      0
#
#       Content Rating                          Genres        Last Updated  \
# 393             Teen                   Communication      August 3, 2018
# 5432        Everyone                          Sports      April 26, 2018
# 8218        Everyone                    Productivity    January 21, 2014
# 7507        Everyone                        Shopping  September 10, 2016
# 4746        Everyone                           Tools       July 31, 2018
# 4518        Everyone                   Communication       July 18, 2018
# 8091        Everyone                 Personalization       June 27, 2018
# 5510        Everyone                          Sports        May 25, 2018
# 5048        Everyone                           Tools     October 3, 2017
# 3695        Everyone         Video Players & Editors        July 5, 2018
# 8280        Everyone                   Entertainment   November 19, 2017
# 2841        Everyone                     Photography    December 4, 2017
# 1442        Everyone                Health & Fitness       July 28, 2018
# 2908        Everyone                     Photography       June 28, 2018
# 3863        Everyone               Maps & Navigation       July 23, 2018
# 7609        Everyone                    Role Playing      August 2, 2018
# 13          Everyone                    Art & Design       June 26, 2018
# 4920        Everyone                           Tools       July 30, 2018
# 638         Everyone                          Dating       July 14, 2018
# 1126        Everyone                         Finance       July 31, 2018
# 2212        Everyone      Entertainment;Pretend Play    December 9, 2017
# 6882        Everyone               Maps & Navigation      August 1, 2018
# 10184       Everyone                         Medical       July 19, 2018
# 7825        Everyone                   Entertainment       July 15, 2017
# 4584        Everyone                      Simulation       June 12, 2018
# 1831        Everyone                           Board        July 4, 2018
# 9275        Everyone                       Education       June 11, 2018
# 6841        Everyone                          Trivia     August 31, 2017
# 10827       Everyone                       Education       June 13, 2018
# 6711        Everyone                 Personalization      March 19, 2018
# 3893        Everyone                           Board        May 13, 2018
# 5882        Everyone         Video Players & Editors       July 23, 2018
# 7245        Everyone                       Lifestyle      March 20, 2017
# 2312        Everyone                         Medical       July 27, 2018
# 9666        Everyone                        Business    January 17, 2018
# 3299        Everyone                           Tools       July 15, 2018
# 3861        Everyone               Maps & Navigation    November 2, 2017
# 995         Everyone                   Entertainment       June 30, 2018
# 242         Everyone                        Business       July 12, 2018
# 1211        Everyone                    Food & Drink        June 8, 2018
# 10230       Everyone                           Tools        June 2, 2017
# 4691      Mature 17+                          Action    January 28, 2018
# 498       Mature 17+                          Dating      August 3, 2018
# 2104        Everyone  Educational;Action & Adventure    January 19, 2018
# 7573        Everyone                           Tools       July 28, 2017
# 4743        Everyone                 Personalization   February 26, 2014
# 9848            Teen                       Education        May 31, 2018
# 7874        Everyone                       Education       June 11, 2018
# 7587        Everyone                   Entertainment      March 27, 2018
# 8075        Everyone                   Entertainment        June 1, 2017
#
#               Current Ver         Android Ver
# 393    Varies with device  Varies with device
# 5432                2.1.3          4.1 and up
# 8218                2.0.0          3.1 and up
# 7507    Bowser4Craigslist          4.0 and up
# 4746                 65.0          4.1 and up
# 4518          7.3(823181)          4.4 and up
# 8091                  3.0          5.1 and up
# 5510                1.1.0          4.4 and up
# 5048              1.8.2.7          5.0 and up
# 3695                  1.2          4.1 and up
# 8280                1.0.1          4.0 and up
# 2841       1.8.0.170824_9           5.0 - 8.0
# 1442   Varies with device  Varies with device
# 2908                6.1.0  Varies with device
# 3863   Varies with device  Varies with device
# 7609                1.2.5          4.4 and up
# 13                  1.0.4          4.4 and up
# 4920                6.1.7          4.2 and up
# 638                   1.0        4.0.3 and up
# 1126   Varies with device  Varies with device
# 2212                  1.8          4.2 and up
# 6882   Varies with device  Varies with device
# 10184               2.7.6          5.0 and up
# 7825                3.2.0          2.3 and up
# 4584                 1.11          4.1 and up
# 1831                2.1.2          4.4 and up
# 9275                1.6.0          4.4 and up
# 6841              3.2.2dk        4.0.3 and up
# 10827              2.0.20        4.0.3 and up
# 6711                  1.2        4.0.3 and up
# 3893   Varies with device  Varies with device
# 5882                  1.0          4.4 and up
# 7245                  1.1          4.1 and up
# 2312               3.25.0          4.4 and up
# 9666                  1.2          4.1 and up
# 3299   Varies with device  Varies with device
# 3861                2.4.1          4.1 and up
# 995    Varies with device  Varies with device
# 242                3.24.1          5.0 and up
# 1211                5.8.5          4.1 and up
# 10230                 2.4          4.4 and up
# 4691                1.0.1          2.3 and up
# 498              1.308.us          4.1 and up
# 2104             6.7.5222          4.1 and up
# 7573                  1.2          4.1 and up
# 4743                  3.1          2.1 and up
# 9848   Varies with device  Varies with device
# 7874                1.0.1          4.0 and up
# 7587                 1.22          4.4 and up
# 8075                  1.8          2.2 and up

# %%
mean_value_rating=df1['Rating'].mean()
mean_value_rating=round(mean_value_rating,1)

# %%
df1['Rating'].fillna(value=mean_value_rating,inplace=True)

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %%
df1[df1['Current Ver'].isna()]
# Out:
#                                    App             Category  Rating Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2      55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1   20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2    4010
# 6803                         BT Master               FAMILY     4.2       0
# 7333                       Dots puzzle               FAMILY     4.0     179
# 7407                   Calculate My IQ               FAMILY     4.2      44
# 7730                            UFO-CQ                TOOLS     4.2       1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     4.2       8
#
#        Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.7M      5,000+  Free      0       Everyone       Art & Design
# 1553    11k  1,000,000+  Free      0       Everyone   Libraries & Demo
# 6322   8.7M    500,000+  Free      0       Everyone              Tools
# 6803   222k        100+  Free      0       Everyone          Education
# 7333    14M     50,000+  Paid  $0.99       Everyone             Puzzle
# 7407   7.2M     10,000+  Free      0       Everyone      Entertainment
# 7730   237k         10+  Paid  $0.99       Everyone              Tools
# 10342  658k      1,000+  Free      0       Everyone  Books & Reference
#
#             Last Updated Current Ver Android Ver
# 15          June 6, 2018         NaN  4.2 and up
# 1553   February 12, 2013         NaN  1.5 and up
# 6322        May 10, 2017         NaN  4.0 and up
# 6803    November 6, 2016         NaN  1.6 and up
# 7333      April 18, 2018         NaN  4.0 and up
# 7407       April 3, 2017         NaN  2.3 and up
# 7730        July 4, 2016         NaN  2.0 and up
# 10342   January 31, 2017         NaN  3.0 and up

# %%
df1.dropna(subset=['Current Ver'],inplace=True)

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       3
# dtype: int64

# %%
df1[df1['Android Ver'].isna()]
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#       Reviews    Size Installs  Type     Price Content Rating  \
# 4453      230     11M   1,000+  Paid     $1.49       Everyone
# 4490      189    2.1M  10,000+  Free         0       Everyone
# 10472    3.0M  1,000+     Free     0  Everyone            NaN
#
#                   Genres    Last Updated Current Ver Android Ver
# 4453     Personalization   July 20, 2018         4.4         NaN
# 4490     Personalization  March 27, 2018         1.1         NaN
# 10472  February 11, 2018          1.0.19  4.0 and up         NaN

# %%
df1.dropna(subset=['Android Ver'],inplace=True)

# %%
df1.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
sns.boxplot(df1['Rating'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df1.drop_duplicates(subset=['App'],inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9648 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9648 non-null   object
#  1   Category        9648 non-null   object
#  2   Rating          9648 non-null   float64
#  3   Reviews         9648 non-null   object
#  4   Size            9648 non-null   object
#  5   Installs        9648 non-null   object
#  6   Type            9648 non-null   object
#  7   Price           9648 non-null   object
#  8   Content Rating  9648 non-null   object
#  9   Genres          9648 non-null   object
#  10  Last Updated    9648 non-null   object
#  11  Current Ver     9648 non-null   object
#  12  Android Ver     9648 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1.0+ MB

# %%
df1['Reviews'] = pd.to_numeric(df1['Reviews'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9648 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9648 non-null   object
#  1   Category        9648 non-null   object
#  2   Rating          9648 non-null   float64
#  3   Reviews         9648 non-null   int64
#  4   Size            9648 non-null   object
#  5   Installs        9648 non-null   object
#  6   Type            9648 non-null   object
#  7   Price           9648 non-null   object
#  8   Content Rating  9648 non-null   object
#  9   Genres          9648 non-null   object
#  10  Last Updated    9648 non-null   object
#  11  Current Ver     9648 non-null   object
#  12  Android Ver     9648 non-null   object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.0+ MB

# %%
# Now we analyse that + and , cause an error so we can remove that
df4=df1['Installs'].str.replace('+','')
# Out:
# <ipython-input-190-7615009da858>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df4=df1['Installs'].str.replace('+','')

# %%
df1['Installs']=df4

# %%
df4=df1['Installs'].str.replace(',','')

# %%
df1['Installs']=df4

# %%
df1['Installs']=pd.to_numeric(df1['Installs'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9648 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9648 non-null   object
#  1   Category        9648 non-null   object
#  2   Rating          9648 non-null   float64
#  3   Reviews         9648 non-null   int64
#  4   Size            9648 non-null   object
#  5   Installs        9648 non-null   int64
#  6   Type            9648 non-null   object
#  7   Price           9648 non-null   object
#  8   Content Rating  9648 non-null   object
#  9   Genres          9648 non-null   object
#  10  Last Updated    9648 non-null   object
#  11  Current Ver     9648 non-null   object
#  12  Android Ver     9648 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 1.0+ MB

# %%
# first we remove dollar
df5=df1['Price'].str.replace('$','')
# Out:
# <ipython-input-197-10af2bb5b51e>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df5=df1['Price'].str.replace('$','')

# %%
df1['Price']=df5

# %%
df5=df1['Price'].str.replace('Everyone','')

# %%
df1['Price']=df5

# %%
df1['Price']=pd.to_numeric(df1['Price'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9648 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9648 non-null   object
#  1   Category        9648 non-null   object
#  2   Rating          9648 non-null   float64
#  3   Reviews         9648 non-null   int64
#  4   Size            9648 non-null   object
#  5   Installs        9648 non-null   int64
#  6   Type            9648 non-null   object
#  7   Price           9648 non-null   float64
#  8   Content Rating  9648 non-null   object
#  9   Genres          9648 non-null   object
#  10  Last Updated    9648 non-null   object
#  11  Current Ver     9648 non-null   object
#  12  Android Ver     9648 non-null   object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.0+ MB

# %%
df1.sample(50)
# Out:
#                                                      App            Category  \
# 5794                        Axetatic - Axe Throwing Game                GAME
# 8553                                        DM EVOLUTION                GAME
# 1062                                                 IKO             FINANCE
# 4695                           BTS V LINE Launcher theme     PERSONALIZATION
# 1771                 Color by Number – New Coloring Book                GAME
# 3231                          Sygic Truck GPS Navigation    TRAVEL_AND_LOCAL
# 9152                                              TETRIS              FAMILY
# 9115                                Currency Exchange DZ             FINANCE
# 6011                      BD Simplist Through Their Eyes              FAMILY
# 8478                           DK Eyewitness Audio Walks    TRAVEL_AND_LOCAL
# 7070                                       bz Basel News  NEWS_AND_MAGAZINES
# 4577   PitchBlack S - Samsung Substratum Theme “For O...     PERSONALIZATION
# 747                        Peak – Brain Games & Training           EDUCATION
# 105                                   Filters for Selfie              BEAUTY
# 4794                                    JW Caleb y Sofia              FAMILY
# 6655                                     Woody's Bar-B-Q      FOOD_AND_DRINK
# 2382                    Open Sesame - Touch Free Control             MEDICAL
# 4632                                             Ustream       VIDEO_PLAYERS
# 9016                                          DW Cleaner               TOOLS
# 9364                           VITEK EH DVR Viewer (Pro)               TOOLS
# 8166                                          TeeTime.cz              SPORTS
# 5903                                      Ultrasound A-Z              FAMILY
# 6000                       BDCast - Bangla Live TV,Radio              FAMILY
# 6299                             All Language Translator               TOOLS
# 10465                        Portable Wi-Fi hotspot Free       COMMUNICATION
# 9393                                     Guess The Emoji                GAME
# 2707                                       Coupon Sherpa            SHOPPING
# 10716                Free Slideshow Maker & Video Editor         PHOTOGRAPHY
# 7469                               Brainf*ck Interpreter              FAMILY
# 2545                                           Instagram              SOCIAL
# 9523                      Train Racing Games 3D 2 Player                GAME
# 5883                      AZ Immune Related AEManagement             MEDICAL
# 4719          W - Weather Forecast & Animated Radar Maps             WEATHER
# 6426                                OTOME of Ikemen cafe              FAMILY
# 1779                                              PLANK!                GAME
# 8336                                    DF-Server Mobile        PRODUCTIVITY
# 7138                                        CB Mobile GA             FINANCE
# 427                                   Puffin Browser Pro       COMMUNICATION
# 7583                                 CN Summer Challenge              FAMILY
# 10803                       Fatal Raid - No.1 Mobile FPS                GAME
# 2169                           All-in-One Mahjong 3 FREE              FAMILY
# 3264                                     HTC Lock Screen               TOOLS
# 7038                                            BZ Bingo              FAMILY
# 581                                           JustDating              DATING
# 9896                                        Autoroute.EU            BUSINESS
# 2126                       Touch Racing 2 - Mini RC Race              FAMILY
# 5573                       AS - News and sports results.              SPORTS
# 2256                          2017 EMRA Antibiotic Guide             MEDICAL
# 2138                                    Frozen Free Fall              FAMILY
# 4564                 Tutorials for R Programming Offline              FAMILY
#
#        Rating   Reviews                Size    Installs  Type  Price  \
# 5794      4.6        29                 31M        1000  Free   0.00
# 8553      2.5       450                 97M       10000  Free   0.00
# 1062      4.7    167168                 20M     1000000  Free   0.00
# 4695      4.8      3283                3.6M      100000  Free   0.00
# 1771      4.7    141529                 24M     5000000  Free   0.00
# 3231      4.2     18294                 28M     1000000  Free   0.00
# 9152      4.0    199808                 57M    10000000  Free   0.00
# 9115      4.2         4                2.5M        1000  Free   0.00
# 6011      4.2         1                 38M          10  Free   0.00
# 8478      2.3         9                 70M        1000  Free   0.00
# 7070      2.2        23                 33M        1000  Free   0.00
# 4577      4.5        90                 37M        1000  Paid   1.99
# 747       4.4    272145  Varies with device    10000000  Free   0.00
# 105       4.3      8572                 25M     1000000  Free   0.00
# 4794      4.6      5227                1.9M      500000  Free   0.00
# 6655      3.7         3                 27M        1000  Free   0.00
# 2382      4.4       197                 20M       10000  Free   0.00
# 4632      4.0     93638                7.3M    10000000  Free   0.00
# 9016      4.2         7                3.0M         500  Free   0.00
# 9364      3.5        78                3.3M       10000  Free   0.00
# 8166      4.6      1641                6.2M       10000  Free   0.00
# 5903      4.5       112                 39M       10000  Free   0.00
# 6000      4.4      7461                 31M     1000000  Free   0.00
# 6299      4.0     29944                2.1M     5000000  Free   0.00
# 10465     4.0      1711                2.1M      100000  Free   0.00
# 9393      4.5     76627                 23M     5000000  Free   0.00
# 2707      4.4      7793                6.1M      500000  Free   0.00
# 10716     4.2    162564                 11M    10000000  Free   0.00
# 7469      4.0        24                1.9M        1000  Free   0.00
# 2545      4.5  66577313  Varies with device  1000000000  Free   0.00
# 9523      4.3    192374                 56M    10000000  Free   0.00
# 5883      3.7         3                7.3M         500  Free   0.00
# 4719      4.2        29                3.5M        5000  Free   0.00
# 6426      4.5      1318                 24M       50000  Free   0.00
# 1779      4.7      7196                 38M      500000  Free   0.00
# 8336      4.9        17                 76M         100  Free   0.00
# 7138      4.2         1                 12M         100  Free   0.00
# 427       4.0     18247  Varies with device      100000  Paid   3.99
# 7583      3.7       985                 49M      100000  Free   0.00
# 10803     4.3     56496                 81M     1000000  Free   0.00
# 2169      4.5       566                 17M       50000  Free   0.00
# 3264      4.1     28250  Varies with device    10000000  Free   0.00
# 7038      4.2         1                 17M         100  Free   0.00
# 581       4.0     13440                 49M      500000  Free   0.00
# 9896      4.2        10                2.7M        1000  Free   0.00
# 2126      4.1     41867                 78M     1000000  Free   0.00
# 5573      3.7     20879                 22M     1000000  Free   0.00
# 2256      4.4        12                3.8M        1000  Paid  16.99
# 2138      4.3   1574197                 37M    50000000  Free   0.00
# 4564      4.2         2                4.4M         500  Free   0.00
#
#       Content Rating                     Genres       Last Updated  \
# 5794    Everyone 10+                     Arcade   October 22, 2017
# 8553        Everyone                       Card      July 23, 2018
# 1062        Everyone                    Finance       July 4, 2018
# 4695        Everyone            Personalization   October 17, 2014
# 1771    Everyone 10+                      Board     August 1, 2018
# 3231        Everyone             Travel & Local     August 2, 2018
# 9152        Everyone                     Puzzle      June 14, 2018
# 9115        Everyone                    Finance  November 10, 2016
# 6011        Everyone                 Simulation   December 4, 2015
# 8478        Everyone             Travel & Local      April 6, 2018
# 7070        Everyone           News & Magazines       June 6, 2018
# 4577        Everyone            Personalization     August 4, 2018
# 747         Everyone      Education;Brain Games     August 3, 2018
# 105         Everyone                     Beauty       May 10, 2018
# 4794        Everyone                  Education  November 20, 2015
# 6655        Everyone               Food & Drink      March 5, 2018
# 2382        Everyone                    Medical     August 2, 2018
# 4632      Mature 17+    Video Players & Editors      July 11, 2018
# 9016        Everyone                      Tools     August 5, 2018
# 9364        Everyone                      Tools   October 11, 2013
# 8166        Everyone                     Sports     August 2, 2018
# 5903        Everyone                  Education       June 5, 2018
# 6000        Everyone              Entertainment       May 20, 2018
# 6299        Everyone                      Tools    October 3, 2015
# 10465       Everyone              Communication   January 11, 2018
# 9393        Everyone                       Word       July 3, 2018
# 2707        Everyone                   Shopping   February 6, 2018
# 10716       Everyone                Photography     August 5, 2018
# 7469      Mature 17+              Entertainment  September 3, 2016
# 2545            Teen                     Social      July 31, 2018
# 9523        Everyone                     Racing    January 9, 2018
# 5883        Everyone                    Medical       May 24, 2018
# 4719        Everyone                    Weather     April 23, 2018
# 6426            Teen                 Simulation      March 5, 2018
# 1779        Everyone                     Arcade      July 17, 2018
# 8336        Everyone               Productivity       June 7, 2016
# 7138        Everyone                    Finance  November 21, 2017
# 427         Everyone              Communication       July 5, 2018
# 7583        Everyone  Entertainment;Brain Games       May 24, 2018
# 10803           Teen                     Action     August 7, 2018
# 2169        Everyone          Board;Brain Games      June 13, 2018
# 3264        Everyone                      Tools     March 21, 2017
# 7038        Everyone              Entertainment      April 3, 2018
# 581       Mature 17+                     Dating     August 3, 2018
# 9896        Everyone                   Business      July 19, 2016
# 2126        Everyone  Racing;Action & Adventure       May 18, 2017
# 5573        Everyone                     Sports       June 9, 2018
# 2256        Everyone                    Medical   January 27, 2017
# 2138        Everyone  Puzzle;Action & Adventure      July 27, 2018
# 4564        Everyone                  Education   December 4, 2017
#
#               Current Ver         Android Ver
# 5794                1.3.3          4.2 and up
# 8553                2.0.9          4.1 and up
# 1062             3.115.27          4.1 and up
# 4695                  4.1        4.0.3 and up
# 1771                2.0.6          4.1 and up
# 3231               13.8.3          4.0 and up
# 9152               3.0.10          3.0 and up
# 9115                  1.0          2.3 and up
# 6011                  1.0          4.1 and up
# 8478              1.0.1.8          4.2 and up
# 7070                1.4.0          5.0 and up
# 4577                 12.6          7.0 and up
# 747               3.14.15          5.0 and up
# 105                 1.1.0          4.0 and up
# 4794                  1.0        4.0.3 and up
# 6655              1.01.03          4.1 and up
# 2382                3.5.7          7.0 and up
# 4632                3.2.2          4.1 and up
# 9016                  1.7          4.0 and up
# 9364               1.2.10          2.2 and up
# 8166              1.18.34          4.0 and up
# 5903                  1.5          4.0 and up
# 6000                4.2.1          4.1 and up
# 6299                  1.6          2.3 and up
# 10465          1.2.5.4-11          2.3 and up
# 9393                8.16g          4.2 and up
# 2707                3.0.3        4.0.3 and up
# 10716                 5.2          4.0 and up
# 7469                1.0.6          2.3 and up
# 2545   Varies with device  Varies with device
# 9523   Varies with device          5.0 and up
# 5883                  1.4          3.2 and up
# 4719                  1.1          4.1 and up
# 6426               1.0.21          4.1 and up
# 1779                1.0.2          4.3 and up
# 8336                1.0.0          4.4 and up
# 7138                1.9.1          4.1 and up
# 427           7.5.3.20547          4.1 and up
# 7583                  1.1          4.4 and up
# 10803             1.5.447          4.0 and up
# 2169             20180609          4.0 and up
# 3264   Varies with device  Varies with device
# 7038                  1.3        4.0.3 and up
# 581                3.10.5        4.0.3 and up
# 9896                  2.6        4.0.3 and up
# 2126              1.4.2.1        2.3.3 and up
# 5573               5.1.13          4.1 and up
# 2256                1.0.5        4.0.3 and up
# 2138                6.7.0          4.2 and up
# 4564                  1.0          4.0 and up

# %%
df1[(df1['Size']=='Varies with device')]
# Out:
#                                                      App             Category  \
# 37                                    Floor Plan Creator       ART_AND_DESIGN
# 42                            Textgram - write on photos       ART_AND_DESIGN
# 52                         Used Cars and Trucks for Sale    AUTO_AND_VEHICLES
# 67                                    Ulysse Speedometer    AUTO_AND_VEHICLES
# 68                                                REPUVE    AUTO_AND_VEHICLES
# ...                                                  ...                  ...
# 10713  My Earthquake Alerts - US & Worldwide Earthquakes              WEATHER
# 10725                                          Posta App  MAPS_AND_NAVIGATION
# 10765                    Chat For Strangers - Video Chat               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
#        Rating  Reviews                Size  Installs  Type  Price  \
# 37        4.1    36639  Varies with device   5000000  Free    0.0
# 42        4.4   295221  Varies with device  10000000  Free    0.0
# 52        4.6    17057  Varies with device   1000000  Free    0.0
# 67        4.3    40211  Varies with device   5000000  Free    0.0
# 68        3.9      356  Varies with device    100000  Free    0.0
# ...       ...      ...                 ...       ...   ...    ...
# 10713     4.4     3471  Varies with device    100000  Free    0.0
# 10725     3.6        8  Varies with device      1000  Free    0.0
# 10765     3.4      622  Varies with device    100000  Free    0.0
# 10826     4.0    88486  Varies with device   5000000  Free    0.0
# 10839     4.5      114  Varies with device      1000  Free    0.0
#
#       Content Rating             Genres        Last Updated  \
# 37          Everyone       Art & Design       July 14, 2018
# 42          Everyone       Art & Design       July 30, 2018
# 52          Everyone    Auto & Vehicles       July 30, 2018
# 67          Everyone    Auto & Vehicles       July 30, 2018
# 68          Everyone    Auto & Vehicles        May 25, 2018
# ...              ...                ...                 ...
# 10713       Everyone            Weather       July 24, 2018
# 10725       Everyone  Maps & Navigation  September 27, 2017
# 10765     Mature 17+             Social        May 23, 2018
# 10826     Mature 17+             Social      March 23, 2018
# 10839     Mature 17+  Books & Reference    January 19, 2015
#
#               Current Ver         Android Ver
# 37     Varies with device        2.3.3 and up
# 42     Varies with device  Varies with device
# 52     Varies with device  Varies with device
# 67     Varies with device  Varies with device
# 68     Varies with device  Varies with device
# ...                   ...                 ...
# 10713  Varies with device  Varies with device
# 10725  Varies with device          4.4 and up
# 10765  Varies with device  Varies with device
# 10826  Varies with device  Varies with device
# 10839  Varies with device  Varies with device
#
# [1226 rows x 13 columns]

# %%
# We check how many apps are free 
df1[(df1['Type']=='Free')]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating   Reviews                Size    Installs  Type  Price  \
# 0         4.1     159.0                 19M     10000.0  Free    0.0
# 1         3.9     967.0                 14M    500000.0  Free    0.0
# 2         4.7   87510.0                8.7M   5000000.0  Free    0.0
# 3         4.5  215644.0                 25M  50000000.0  Free    0.0
# 4         4.3     967.0                2.8M    100000.0  Free    0.0
# ...       ...       ...                 ...         ...   ...    ...
# 10836     4.5      38.0                 53M      5000.0  Free    0.0
# 10837     5.0       4.0                3.6M       100.0  Free    0.0
# 10838     NaN       3.0                9.5M      1000.0  Free    0.0
# 10839     4.5     114.0  Varies with device      1000.0  Free    0.0
# 10840     4.5  398307.0                 19M  10000000.0  Free    0.0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10039 rows x 13 columns]

# %%
# We check how many apps are Paid
df1[(df1['Type']=='Paid')]
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# 476                        Moco+ - Chat, Meet People              DATING
# 477                                       Calculator              DATING
# ...                                              ...                 ...
# 10735                                    FP VoiceBot              FAMILY
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
# 10798                           Word Search Tab 1 FR              FAMILY
#
#        Rating  Reviews                Size  Installs  Type  Price  \
# 234       4.7    11442                6.8M    100000  Paid   4.99
# 235       4.8    10295                 39M    100000  Paid   4.99
# 427       4.0    18247  Varies with device    100000  Paid   3.99
# 476       4.2     1545  Varies with device     10000  Paid   3.99
# 477       2.6       57                6.2M      1000  Paid   6.99
# ...       ...      ...                 ...       ...   ...    ...
# 10735     4.2       17                157k       100  Paid   0.99
# 10760     4.4       35                2.4M      1000  Paid   7.99
# 10782     3.8      252                 11M     10000  Paid  16.99
# 10785     4.2     1405                9.5M     10000  Paid   1.20
# 10798     4.2        0               1020k        50  Paid   1.04
#
#       Content Rating            Genres       Last Updated  Current Ver  \
# 234         Everyone          Business     March 25, 2018        1.5.2
# 235         Everyone          Business     April 11, 2017        3.4.6
# 427         Everyone     Communication       July 5, 2018  7.5.3.20547
# 476       Mature 17+            Dating      June 19, 2018      2.6.139
# 477         Everyone            Dating   October 25, 2017        1.1.6
# ...              ...               ...                ...          ...
# 10735     Mature 17+     Entertainment  November 25, 2015          1.2
# 10760       Everyone  Health & Fitness     August 8, 2018        1.9.3
# 10782           Teen            Action  February 27, 2015         2.22
# 10785       Everyone            Puzzle       June 5, 2018          2.7
# 10798       Everyone            Puzzle   February 6, 2012          1.1
#
#       Android Ver
# 234    4.0 and up
# 235    3.0 and up
# 427    4.1 and up
# 476    4.1 and up
# 477    4.0 and up
# ...           ...
# 10735  2.1 and up
# 10760  4.2 and up
# 10782  5.0 and up
# 10785  2.3 and up
# 10798  3.0 and up
#
# [753 rows x 13 columns]

# %%
for i in df1.index:
  a=df1.loc[i,'Size']
  if a.endswith('k'):
    a=a.replace('k','')
    a=float(a)
    a= a/1048576
    a=str(a)
    a=a+'M'
  df1.loc[i,'Size']=a

# %%
df1.sample(50)
# Out:
#                                                      App             Category  \
# 5543                      Wayfair - Shop All Things Home             SHOPPING
# 969                         Yidio: TV Show & Movie Guide        ENTERTAINMENT
# 10000                                             Mee-EW                TOOLS
# 9915                                     GastroHunter.EU            LIFESTYLE
# 10696                                         FO Interim        COMMUNICATION
# 8219                          10,000 Quotes DB (Premium)  BOOKS_AND_REFERENCE
# 4189           DNS Changer - BEST (Gprs/Edge/3G/H/H+/4G)                TOOLS
# 6389                                Bk Bee Sales Manager             BUSINESS
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9597                      Dragonplay™ Poker Texas Holdem                 GAME
# 4719          W - Weather Forecast & Animated Radar Maps              WEATHER
# 6064                                      Be My Princess               FAMILY
# 33                                    Easy Origami Ideas       ART_AND_DESIGN
# 8808                              MegaNDS (NDS Emulator)                 GAME
# 1513                         Trulia Mortgage Calculators       HOUSE_AND_HOME
# 2678                          bigbasket - online grocery             SHOPPING
# 1785                                         PUBG MOBILE                 GAME
# 3574                                         Cloud Print         PRODUCTIVITY
# 10737                                          FP Legacy  MAPS_AND_NAVIGATION
# 10003                                           The List   NEWS_AND_MAGAZINES
# 5493                              AdventureQuest Dragons               FAMILY
# 6478                                           postit.bm             SHOPPING
# 3449                       Lavender Emoji Keyboard Theme      PERSONALIZATION
# 1326                     Daily Yoga - Yoga Fitness Plans   HEALTH_AND_FITNESS
# 7535                                              CL-App              MEDICAL
# 7752                                Toughest Game Ever 2                 GAME
# 58                                     Restart Navigator    AUTO_AND_VEHICLES
# 3389                       Wallpapers HD, 4K Backgrounds      PERSONALIZATION
# 8916                                    Portes du Soleil               SPORTS
# 4177                                     G-NetReport Pro                TOOLS
# 3984                   Cardi B HD Wallpapers Lock Screen      PERSONALIZATION
# 10780     Modern Counter 3: FPS Multiplayers battlegro 3               FAMILY
# 6371                             Coupons for Burger King       FOOD_AND_DRINK
# 5254                             AJ Styles HD Wallpapers       ART_AND_DESIGN
# 2740                                           Nordstrom             SHOPPING
# 10197                                   Facebook Creator               SOCIAL
# 2215                                Hello Kitty Lunchbox               FAMILY
# 5080                                          Afterlight          PHOTOGRAPHY
# 5572                                       AR Sport Cars               FAMILY
# 8759   dr.fone - Recovery & Transfer wirelessly & Backup                TOOLS
# 8932                                           Sports DV            LIFESTYLE
# 5176                                         Mitchell AH              MEDICAL
# 9712                                 EP Research Service  BOOKS_AND_REFERENCE
# 8355                                        Aproveita DF            LIFESTYLE
# 1595                                         Galaxy Gift            LIFESTYLE
# 5670                              AU Results 2017 Auzone               FAMILY
# 5568   Mind Map AR, Augmented Reality ARCore Mind Map...         PRODUCTIVITY
# 6972                         Commando Adventure Assassin                 GAME
# 8385                       Coupon Mob - Discount Coupons             SHOPPING
# 6462                              Borneo Bible, BM Bible  BOOKS_AND_REFERENCE
#
#        Rating  Reviews                     Size   Installs  Type  Price  \
# 5543      4.5    20247                      47M    5000000  Free   0.00
# 969       3.9    27424       Varies with device    1000000  Free   0.00
# 10000     4.2        0                      17M          5  Free   0.00
# 9915      4.2        1                     1.5M         10  Free   0.00
# 10696     4.2        1                      11M        100  Free   0.00
# 8219      4.1       70                     3.5M        500  Paid   0.99
# 4189      4.3      123                     1.9M       5000  Free   0.00
# 6389      4.2        0                     2.1M          5  Paid   0.99
# 10839     4.5      114       Varies with device       1000  Free   0.00
# 9597      4.5   197979       Varies with device    1000000  Free   0.00
# 4719      4.2       29                     3.5M       5000  Free   0.00
# 6064      4.2     3103                     8.8M     100000  Free   0.00
# 33        4.2     1015                      11M     100000  Free   0.00
# 8808      3.4     2218                      11M     500000  Free   0.00
# 1513      4.1       81                      16M      50000  Free   0.00
# 2678      4.3   216741       Varies with device    5000000  Free   0.00
# 1785      4.4  3715656                      36M   50000000  Free   0.00
# 3574      4.1   282460       Varies with device  500000000  Free   0.00
# 10737     4.0        3                      44M       1000  Free   0.00
# 10003     3.5       66                      12M      10000  Free   0.00
# 5493      3.9    10114                      48M     100000  Free   0.00
# 6478      4.2        1                      16M        500  Free   0.00
# 3449      4.1    12008                     6.1M    1000000  Free   0.00
# 1326      4.4    70769                      35M    5000000  Free   0.00
# 7535      4.7        6                     5.2M        100  Free   0.00
# 7752      4.6   293086       Varies with device    5000000  Free   0.00
# 58        4.0     1403  0.00019168853759765625M     100000  Free   0.00
# 3389      4.7   273994                      12M   10000000  Free   0.00
# 8916      3.1      500                      39M      50000  Free   0.00
# 4177      4.2        0                     1.6M         10  Paid  25.99
# 3984      4.5        2                      10M        500  Free   0.00
# 10780     4.1       17                      50M       1000  Free   0.00
# 6371      4.5       41                     4.0M        500  Free   0.00
# 5254      4.8       48                      25M       5000  Free   0.00
# 2740      4.6     2278                      12M     500000  Free   0.00
# 10197     4.2     3895       Varies with device    1000000  Free   0.00
# 2215      4.2    51838                      15M    5000000  Free   0.00
# 5080      4.3    50893                      35M    1000000  Free   0.00
# 5572      3.6      284                      70M      10000  Free   0.00
# 8759      3.7    23347                     7.6M    5000000  Free   0.00
# 8932      2.1       86                      29M      10000  Free   0.00
# 5176      4.2        0                      29M         50  Free   0.00
# 9712      4.7       14                      27M       1000  Free   0.00
# 8355      4.2        0                     3.3M          1  Free   0.00
# 1595      4.4    95557                      16M   10000000  Free   0.00
# 5670      3.8      762                     4.1M     100000  Free   0.00
# 5568      4.2       29                      35M       5000  Free   0.00
# 6972      4.0    51067                      48M    5000000  Free   0.00
# 8385      3.0        2                     1.3M        100  Free   0.00
# 6462      4.9      659                     5.0M      10000  Free   0.00
#
#       Content Rating             Genres        Last Updated  \
# 5543        Everyone           Shopping      August 3, 2018
# 969             Teen      Entertainment       July 31, 2018
# 10000       Everyone              Tools      August 2, 2018
# 9915        Everyone          Lifestyle      April 23, 2015
# 10696       Everyone      Communication      March 14, 2017
# 8219        Everyone  Books & Reference     August 30, 2013
# 4189        Everyone              Tools  September 30, 2017
# 6389        Everyone           Business   December 16, 2017
# 10839     Mature 17+  Books & Reference    January 19, 2015
# 9597            Teen               Card      August 7, 2018
# 4719        Everyone            Weather      April 23, 2018
# 6064            Teen      Entertainment  September 19, 2017
# 33          Everyone       Art & Design     January 6, 2018
# 8808        Everyone             Arcade    October 18, 2017
# 1513        Everyone       House & Home   February 16, 2018
# 2678        Everyone           Shopping      August 6, 2018
# 1785            Teen             Action       July 24, 2018
# 3574        Everyone       Productivity        May 23, 2018
# 10737       Everyone  Maps & Navigation        July 2, 2018
# 10003       Everyone   News & Magazines        June 1, 2017
# 5493        Everyone             Casual       June 13, 2018
# 6478        Everyone           Shopping      March 14, 2018
# 3449        Everyone    Personalization        May 27, 2016
# 1326        Everyone   Health & Fitness       July 24, 2018
# 7535        Everyone            Medical   February 17, 2017
# 7752        Everyone             Action    October 22, 2015
# 58          Everyone    Auto & Vehicles     August 26, 2014
# 3389        Everyone    Personalization       July 23, 2018
# 8916        Everyone             Sports   February 16, 2018
# 4177        Everyone              Tools       June 14, 2018
# 3984      Mature 17+    Personalization       June 10, 2018
# 10780       Everyone           Strategy      March 16, 2018
# 6371            Teen       Food & Drink       July 17, 2018
# 5254        Everyone       Art & Design      August 4, 2018
# 2740        Everyone           Shopping       July 15, 2018
# 10197           Teen             Social       June 27, 2018
# 2215        Everyone  Casual;Creativity   November 21, 2017
# 5080        Everyone        Photography   November 20, 2014
# 5572        Everyone         Simulation       June 10, 2017
# 8759        Everyone              Tools        May 28, 2018
# 8932        Everyone          Lifestyle       July 17, 2018
# 5176        Everyone            Medical        May 23, 2018
# 9712        Everyone  Books & Reference       March 5, 2018
# 8355        Everyone          Lifestyle      August 2, 2018
# 1595        Everyone          Lifestyle       July 23, 2018
# 5670        Everyone          Education    February 1, 2017
# 5568        Everyone       Productivity       July 26, 2018
# 6972            Teen             Action        May 29, 2018
# 8385        Everyone           Shopping        May 30, 2018
# 6462        Everyone  Books & Reference     August 28, 2017
#
#               Current Ver         Android Ver
# 5543              4.70.30          4.1 and up
# 969    Varies with device  Varies with device
# 10000               1.0.1          4.1 and up
# 9915                  1.0          4.3 and up
# 10696                 1.0          4.1 and up
# 8219                  1.3          2.1 and up
# 4189                  1.2          4.0 and up
# 6389                  1.0          4.1 and up
# 10839  Varies with device  Varies with device
# 9597   Varies with device  Varies with device
# 4719                  1.1          4.1 and up
# 6064                  6.5          2.2 and up
# 33                  1.1.0          4.1 and up
# 8808                  2.0          4.0 and up
# 1513                2.1.0          4.4 and up
# 2678                4.6.0          4.1 and up
# 1785                0.7.0          4.3 and up
# 3574   Varies with device  Varies with device
# 10737               3.4.0          4.0 and up
# 10003                6.11          4.1 and up
# 5493               1.0.63          4.0 and up
# 6478                 2.53          4.1 and up
# 3449                  5.0          4.0 and up
# 1326               6.2.73          4.0 and up
# 7535                  1.1          4.0 and up
# 7752                  8.1        4.0.3 and up
# 58                  1.0.1          2.2 and up
# 3389               2.3.27          4.4 and up
# 8916               10.012          4.1 and up
# 4177                  5.0          4.0 and up
# 3984                  1.3        4.0.3 and up
# 10780                  15          4.1 and up
# 6371                  1.0          5.0 and up
# 5254                1.1.1          4.1 and up
# 2740        3.28.1.3.1359          4.4 and up
# 10197        176.0.0.29.0          4.4 and up
# 2215                  1.6          4.1 and up
# 5080                1.0.6        4.0.3 and up
# 5572                  1.0          4.1 and up
# 8759            3.2.0.169          2.3 and up
# 8932                3.0.3          4.3 and up
# 5176          300000.1.08        4.0.3 and up
# 9712                  1.9          4.1 and up
# 8355                  1.0          4.0 and up
# 1595                7.0.8        4.0.3 and up
# 5670                  2.0          4.0 and up
# 5568                 1.23          7.0 and up
# 6972                 1.18          4.1 and up
# 8385                  6.0          3.0 and up
# 6462                4.4.5          4.0 and up

# %%
plt.figure(figsize=(16,6))
plt.bar(list(df1.columns),list(df1.isnull().sum()))
plt.xlabel('Columns')
plt.ylabel('Null Value')
plt.title('Visualization of Null/Missing value')
plt.show()

# %%
df1.dropna().shape
#10829 Rows has not any null value
# Out:
# (9648, 13)

# %%
df1.dropna(how='all').shape
#It is clear that we dont have any Row which has totally empty
# Out:
# (9648, 13)

# %%
df1['Last Updated']= pd.to_datetime(df1['Last Updated'])
# We convert Last updated coloum which is needed to have in datetime dtype but it is in object to we convert this

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9648 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9648 non-null   object
#  1   Category        9648 non-null   object
#  2   Rating          9648 non-null   float64
#  3   Reviews         9648 non-null   int64
#  4   Size            9648 non-null   object
#  5   Installs        9648 non-null   int64
#  6   Type            9648 non-null   object
#  7   Price           9648 non-null   float64
#  8   Content Rating  9648 non-null   object
#  9   Genres          9648 non-null   object
#  10  Last Updated    9648 non-null   datetime64[ns]
#  11  Current Ver     9648 non-null   object
#  12  Android Ver     9648 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(8)
# memory usage: 1.3+ MB

# %%
df1.sample(50)
# Out:
#                                                      App             Category  \
# 1715                                         Word Search                 GAME
# 3066    Yahoo Sports - scores, stats, news, & highlights               SPORTS
# 506                                                Howlr               DATING
# 2851                      Beauty Makeup – Photo Makeover          PHOTOGRAPHY
# 6114                                            Bf Light             BUSINESS
# 2854                      Muzy - Share photos & collages          PHOTOGRAPHY
# 9892                             Have your say on Europe        COMMUNICATION
# 4220                                               Helix                 GAME
# 10358                           Theme For Galaxy Note FE      PERSONALIZATION
# 782                                         Khan Academy            EDUCATION
# 4927                       All Type Ac Repair & Services            LIFESTYLE
# 1995                                Bubble Shooter Space                 GAME
# 5879                          Long Realty AZ Home Search            LIFESTYLE
# 8627                          Mahalaxmi Dindarshika 2018         PRODUCTIVITY
# 10289                                       Female Daily               BEAUTY
# 9732   Multi Surgery ER Emergency Hospital : Doctor Game               FAMILY
# 7792                      Jetting for Honda CR dirt bike               SPORTS
# 2771                                                ASOS             SHOPPING
# 8789                       Dr.Android Repair Master 2017         PRODUCTIVITY
# 10776                                   Monster Ride Pro                 GAME
# 1051                                     The postal bank              FINANCE
# 8688                                           Dp For FB          PHOTOGRAPHY
# 3741                               Asahi Shimbun Digital   NEWS_AND_MAGAZINES
# 9410                                     EI HabitTracker               FAMILY
# 7600                  Dreamland Arcade - Steven Universe                 GAME
# 5206                                   ai robot keyboard      PERSONALIZATION
# 3465                                   Microsoft OneNote         PRODUCTIVITY
# 5283                        Crisis Action: 2018 NO.1 FPS                 GAME
# 10779                              Fortune Quest: Savior               FAMILY
# 3364                         Funny Alarm Clock Ringtones      PERSONALIZATION
# 7388                                             CI View             BUSINESS
# 7609          Champions and Challengers - Adventure Time               FAMILY
# 308                                   Funny Jokes Photos               COMICS
# 9317                      EG SIM CARD (EGSIMCARD, 이지심카드)             BUSINESS
# 5764                           Modern Action Commando 3D                 GAME
# 7422                             CJ'S TIRE AND AUTO INC.         PRODUCTIVITY
# 7079                                         Filmi Gaane               FAMILY
# 4624                              MBTA GPS - Track the T  MAPS_AND_NAVIGATION
# 5231                                        AJ Reminders  MAPS_AND_NAVIGATION
# 3904                                  WhatsApp Messenger        COMMUNICATION
# 6863      Bacterial vaginosis Treatment - Sexual disease   HEALTH_AND_FITNESS
# 10506                            Hair saloon - Spa salon               FAMILY
# 10305                                   RD/FD Calculator              FINANCE
# 4079                         Mobile Security & Antivirus         PRODUCTIVITY
# 5661                                            AU Spark               FAMILY
# 1204   Delivery trough - delivery trough delivery trough       FOOD_AND_DRINK
# 7014                      SegPlay Mobile Paint by Number               FAMILY
# 4732   App Lock: Locker w/ fingerprint, Parental Control                TOOLS
# 8712              Name Art DP - Focus n Filter Text 2018       ART_AND_DESIGN
# 340                                                Gmail        COMMUNICATION
#
#        Rating     Reviews                Size      Installs  Type  Price  \
# 1715      4.7    295305.0                3.9M  1.000000e+07  Free   0.00
# 3066      4.5     32386.0                 19M  1.000000e+06  Free   0.00
# 506       3.9       105.0                 27M  5.000000e+03  Free   0.00
# 2851      4.3     21730.0                 19M  1.000000e+06  Free   0.00
# 6114      4.2         6.0                 11M  1.000000e+03  Free   0.00
# 2854      4.4     70189.0                 13M  5.000000e+06  Free   0.00
# 9892      3.8        19.0                 21M  5.000000e+02  Free   0.00
# 4220      3.9      2454.0                 37M  5.000000e+05  Free   0.00
# 10358     4.2         0.0                7.5M  1.000000e+02  Free   0.00
# 782       4.6     85375.0                 21M  5.000000e+06  Free   0.00
# 4927      4.3        45.0                2.2M  1.000000e+04  Free   0.00
# 1995      4.2      4355.0  Varies with device  1.000000e+06  Free   0.00
# 5879      4.4       132.0                 33M  1.000000e+04  Free   0.00
# 8627      4.2     25427.0                9.2M  1.000000e+06  Free   0.00
# 10289     3.9      4354.0                 42M  1.000000e+05  Free   0.00
# 9732      4.1       227.0                 69M  1.000000e+04  Free   0.00
# 7792      4.1         7.0                3.4M  1.000000e+02  Paid   3.49
# 2771      4.7    181798.0                 22M  1.000000e+07  Free   0.00
# 8789      3.8      1205.0                4.3M  1.000000e+05  Free   0.00
# 10776     5.0         1.0                 24M  1.000000e+01  Free   0.00
# 1051      3.7     36718.0  Varies with device  5.000000e+06  Free   0.00
# 8688      4.5        12.0                2.0M  1.000000e+03  Free   0.00
# 3741      3.1       735.0                6.3M  5.000000e+05  Free   0.00
# 9410      4.2         2.0                981k  1.000000e+02  Free   0.00
# 7600      4.0      6386.0                 24M  5.000000e+05  Free   0.00
# 5206      4.7      1891.0                1.9M  1.000000e+05  Free   0.00
# 3465      4.4    480643.0  Varies with device  1.000000e+08  Free   0.00
# 5283      4.3    807226.0                 34M  1.000000e+07  Free   0.00
# 10779     3.6       135.0                 75M  1.000000e+04  Free   0.00
# 3364      4.5     15633.0                 14M  1.000000e+06  Free   0.00
# 7388      4.2         2.0                9.9M  1.000000e+02  Free   0.00
# 7609      4.6     51973.0                 27M  1.000000e+06  Free   0.00
# 308       4.4        39.0                4.3M  1.000000e+04  Free   0.00
# 9317      2.9       322.0                1.5M  5.000000e+04  Free   0.00
# 5764      4.2       492.0                 63M  1.000000e+05  Free   0.00
# 7422      5.0         5.0                 11M  1.000000e+02  Free   0.00
# 7079      4.4       572.0  Varies with device  1.000000e+05  Free   0.00
# 4624      3.8        82.0                5.6M  5.000000e+03  Free   0.00
# 5231      4.2         0.0                3.2M  1.000000e+01  Free   0.00
# 3904      4.4  69109672.0  Varies with device  1.000000e+09  Free   0.00
# 6863      5.0         2.0                5.9M  5.000000e+02  Free   0.00
# 10506     4.2     38473.0                 23M  1.000000e+07  Free   0.00
# 10305     4.4        92.0                1.5M  1.000000e+04  Free   0.00
# 4079      4.7    564759.0  Varies with device  1.000000e+07  Free   0.00
# 5661      3.7       681.0                8.2M  1.000000e+04  Free   0.00
# 1204      4.3     58316.0  Varies with device  5.000000e+06  Free   0.00
# 7014      3.7      1478.0                 43M  1.000000e+05  Free   0.00
# 4732      4.5     37607.0  Varies with device  1.000000e+06  Free   0.00
# 8712      4.3       132.0                7.7M  1.000000e+04  Free   0.00
# 340       4.3   4604324.0  Varies with device  1.000000e+09  Free   0.00
#
#       Content Rating               Genres Last Updated         Current Ver  \
# 1715        Everyone                 Word   2018-06-06               1.1.3
# 3066        Everyone               Sports   2018-08-01               7.8.0
# 506       Mature 17+               Dating   2018-06-19               1.0.4
# 2851        Everyone          Photography   2018-05-23               1.6.0
# 6114        Everyone             Business   2017-02-09                 1.0
# 2854            Teen          Photography   2015-08-11              4.0.10
# 9892        Everyone        Communication   2018-04-19               1.1.0
# 4220        Everyone               Arcade   2017-09-10                 1.2
# 10358       Everyone      Personalization   2018-04-19                 1.1
# 782         Everyone            Education   2018-07-27               5.0.0
# 4927        Everyone            Lifestyle   2017-12-26                 0.8
# 1995        Everyone               Casual   2017-07-17                 1.6
# 5879        Everyone            Lifestyle   2018-03-06        5.805.180306
# 8627        Everyone         Productivity   2018-01-05                18.0
# 10289           Teen               Beauty   2018-08-06               2.5.1
# 9732            Teen          Educational   2018-06-21                 1.2
# 7792        Everyone               Sports   2016-04-13                 2.2
# 2771        Everyone             Shopping   2018-07-30               4.4.9
# 8789        Everyone         Productivity   2018-06-10                   2
# 10776       Everyone               Racing   2018-03-05                 2.0
# 1051        Everyone              Finance   2018-07-16  Varies with device
# 8688            Teen          Photography   2017-10-19                 1.0
# 3741        Everyone     News & Magazines   2018-07-25               6.3.0
# 9410        Everyone            Education   2017-08-17         1.40.170809
# 7600        Everyone               Arcade   2017-11-19                0.99
# 5206        Everyone      Personalization   2018-05-24            10001008
# 3465        Everyone         Productivity   2018-07-22    16.0.10325.20024
# 5283            Teen               Action   2018-07-11               3.0.2
# 10779   Everyone 10+         Role Playing   2018-06-01               1.022
# 3364        Everyone      Personalization   2017-03-09                 1.1
# 7388        Everyone             Business   2017-04-19                 2.9
# 7609        Everyone         Role Playing   2018-08-02               1.2.5
# 308     Everyone 10+               Comics   2018-07-03                 1.1
# 9317        Everyone             Business   2017-03-28                2.13
# 5764            Teen               Action   2017-04-06                 1.0
# 7422        Everyone         Productivity   2018-05-30               1.0.1
# 7079        Everyone        Entertainment   2017-08-17  Varies with device
# 4624        Everyone    Maps & Navigation   2018-02-23               5.1.0
# 5231        Everyone    Maps & Navigation   2018-01-27                 1.0
# 3904        Everyone        Communication   2018-08-03  Varies with device
# 6863        Everyone     Health & Fitness   2018-06-25                 2.0
# 10506       Everyone  Casual;Pretend Play   2018-04-11               1.0.5
# 10305       Everyone              Finance   2017-01-31               1.2.1
# 4079        Everyone         Productivity   2018-07-27  Varies with device
# 5661        Everyone            Education   2018-08-01                5.06
# 1204        Everyone         Food & Drink   2018-07-25  Varies with device
# 7014        Everyone               Casual   2017-04-22              4.0.15
# 4732        Everyone                Tools   2018-04-04  Varies with device
# 8712        Everyone         Art & Design   2018-01-04                   1
# 340         Everyone        Communication   2018-08-02  Varies with device
#
#               Android Ver
# 1715           3.0 and up
# 3066           5.1 and up
# 506            4.4 and up
# 2851           4.0 and up
# 6114           4.1 and up
# 2854           4.0 and up
# 9892           4.1 and up
# 4220           4.0 and up
# 10358          4.1 and up
# 782            4.1 and up
# 4927           4.1 and up
# 1995           2.3 and up
# 5879           4.1 and up
# 8627           4.0 and up
# 10289        4.0.3 and up
# 9732           4.0 and up
# 7792           3.0 and up
# 2771           4.4 and up
# 8789           4.0 and up
# 10776          2.3 and up
# 1051   Varies with device
# 8688           4.1 and up
# 3741         4.0.3 and up
# 9410         4.0.3 and up
# 7600           5.1 and up
# 5206         4.0.3 and up
# 3465           4.4 and up
# 5283         4.0.3 and up
# 10779          4.4 and up
# 3364         4.0.3 and up
# 7388           4.1 and up
# 7609           4.4 and up
# 308            4.2 and up
# 9317           2.2 and up
# 5764         4.0.3 and up
# 7422           4.1 and up
# 7079   Varies with device
# 4624           4.1 and up
# 5231           4.2 and up
# 3904   Varies with device
# 6863         4.0.3 and up
# 10506          4.1 and up
# 10305        4.0.3 and up
# 4079   Varies with device
# 5661           4.4 and up
# 1204   Varies with device
# 7014           2.3 and up
# 4732   Varies with device
# 8712           4.1 and up
# 340    Varies with device

# %%
df1.describe()
# Out:
#             Rating       Reviews      Installs        Price
# count  9648.000000  9.648000e+03  9.648000e+03  9648.000000
# mean      4.177353  2.168369e+05  7.786211e+06     1.100193
# std       0.494567  1.832349e+06  5.378830e+07    16.861727
# min       1.000000  0.000000e+00  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01  1.000000e+03     0.000000
# 50%       4.200000  9.690000e+02  1.000000e+05     0.000000
# 75%       4.500000  2.944925e+04  1.000000e+06     0.000000
# max       5.000000  7.815831e+07  1.000000e+09   400.000000

# %%
df1.to_csv('/content/drive/MyDrive/Almabetter Data science/Data/updatedplaystore.csv', encoding='utf-8', index=False)

# %%
# Now we can make our second Dataset analysis ready
df2=pd.read_csv(path1+'/User Reviews.csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
df2.head(10)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
# 6  10 Best Foods for You                                            Amazing
# 7  10 Best Foods for You                                                NaN
# 8  10 Best Foods for You                               Looking forward app,
# 9  10 Best Foods for You              It helpful site ! It help foods get !
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000
# 6  Positive                0.60                0.900000
# 7       NaN                 NaN                     NaN
# 8   Neutral                0.00                0.000000
# 9   Neutral                0.00                0.000000

# %%
df2.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
df2.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
df2.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
# Out:
# array(['10 Best Foods for You', '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#        '11st', ..., 'Hotwire Hotel & Car Rental App',
#        'Housing-Real Estate & Property', 'Houzz Interior Design Ideas'],
#       dtype=object)

# %%
df2.loc[:].nunique()
# Out:
# App                        1074
# Translated_Review         27994
# Sentiment                     3
# Sentiment_Polarity         5410
# Sentiment_Subjectivity     4474
# dtype: int64

# %%
df2['App'].unique()
# Out:
# array(['10 Best Foods for You', '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#        '11st', ..., 'Hotwire Hotel & Car Rental App',
#        'Housing-Real Estate & Property', 'Houzz Interior Design Ideas'],
#       dtype=object)

# %%
df2['Sentiment'].unique()
# Out:
# array(['Positive', nan, 'Neutral', 'Negative'], dtype=object)

# %%
df2['Sentiment_Polarity'].unique()
# Out:
# array([ 1.        ,  0.25      ,         nan, ..., -0.52857143,
#        -0.37777778,  0.17333333])

# %%
df2['Sentiment_Subjectivity'].unique()
# Out:
# array([0.53333333, 0.28846154,        nan, ..., 0.51145833, 0.7172619 ,
#        0.2594697 ])

# %%
df2['Translated_Review'].unique()
# Out:
# array(['I like eat delicious food. That\'s I\'m cooking food myself, case "10 Best Foods" helps lot, also "Best Before (Shelf Life)"',
#        'This help eating healthy exercise regular basis', nan, ...,
#        'Dumb app, I wanted post property rent give option. Website work. Waste time space phone.',
#        'I property business got link SMS happy performance still guys need raise bar guys Cheers',
#        'Useless app, I searched flats kondapur, Hyderabad . None number reachable I know flats unavailable would keep posts active'],
#       dtype=object)

# %%
Sentiment	= df2.groupby('Sentiment')

# %%
Sentiment.size().sort_values(ascending=False)
# Out:
# Sentiment
# Positive    23998
# Negative     8271
# Neutral      5163
# dtype: int64

# %%
df2[df2['Sentiment'].isna()]
# Out:
#                                App Translated_Review Sentiment  \
# 2            10 Best Foods for You               NaN       NaN
# 7            10 Best Foods for You               NaN       NaN
# 15           10 Best Foods for You               NaN       NaN
# 102          10 Best Foods for You               NaN       NaN
# 107          10 Best Foods for You               NaN       NaN
# ...                            ...               ...       ...
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 2                     NaN                     NaN
# 7                     NaN                     NaN
# 15                    NaN                     NaN
# 102                   NaN                     NaN
# 107                   NaN                     NaN
# ...                   ...                     ...
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN
#
# [26863 rows x 5 columns]

# %%
df2.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
df2.dropna().shape
# Out:
# (37427, 5)

# %%
plt.figure(figsize=(16,6))
plt.bar(list(df2.columns),list(df2.isnull().sum()))
plt.xlabel('Columns')
plt.ylabel('Null Value')
plt.title('Visualization of Null/Missing value')
plt.show()

# %%
df2.dropna(how='all',subset=['Translated_Review','Sentiment','Sentiment_Polarity','Sentiment_Subjectivity'])
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# 64222  Most ads older many agents ..not much owner po...  Positive
# 64223  If photos posted portal load, fit purpose. I'm...  Positive
# 64226  Dumb app, I wanted post property rent give opt...  Negative
# 64227  I property business got link SMS happy perform...  Positive
# 64230  Useless app, I searched flats kondapur, Hydera...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 3                0.400000                0.875000
# 4                1.000000                0.300000
# 5                1.000000                0.300000
# ...                   ...                     ...
# 64222            0.173333                0.486667
# 64223            0.225000                0.447222
# 64226           -0.287500                0.250000
# 64227            0.800000                1.000000
# 64230           -0.316667                0.400000
#
# [37432 rows x 5 columns]

# %%
df2.dropna(how='all',subset=['Translated_Review','Sentiment','Sentiment_Polarity','Sentiment_Subjectivity'],inplace=True)

# %%
plt.figure(figsize=(16,6))
plt.bar(list(df2.columns),list(df2.isnull().sum()))
plt.xlabel('Columns')
plt.ylabel('Null Value')
plt.title('Visualization of Null/Missing value')
plt.show()

# %%
df2[df2['Translated_Review'].isna()]
# Out:
#                                              App Translated_Review Sentiment  \
# 268                                         11st               NaN   Neutral
# 15048        Birds Sounds Ringtones & Wallpapers               NaN   Neutral
# 22092             Calorie Counter - MyFitnessPal               NaN   Neutral
# 31623                                  DC Comics               NaN   Neutral
# 52500  Garden Photo Frames - Garden Photo Editor               NaN   Neutral
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 268                   0.0                     0.0
# 15048                 0.0                     0.0
# 22092                 0.0                     0.0
# 31623                 0.0                     0.0
# 52500                 0.0                     0.0

# %%
df2.dropna(subset=['Translated_Review'],inplace=True)

# %%
df2.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37427 entries, 0 to 64230
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     37427 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37427 non-null  object
#  3   Sentiment_Polarity      37427 non-null  float64
#  4   Sentiment_Subjectivity  37427 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.7+ MB

# %%
plt.figure(figsize=(16,6))
plt.bar(list(df2.columns),list(df2.isnull().sum()))
plt.xlabel('Columns')
plt.ylabel('Null Value')
plt.title('Visualization of Null/Missing value')
plt.show()

# %%
df2.to_csv('/content/drive/MyDrive/Almabetter Data science/Data/updatedplaystore_review_1.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***

# %%
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10000.0  Free     0       Everyone
# 1     967   14M    500000.0  Free     0       Everyone
# 2   87510  8.7M   5000000.0  Free     0       Everyone
# 3  215644   25M  50000000.0  Free     0           Teen
# 4     967  2.8M    100000.0  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up
