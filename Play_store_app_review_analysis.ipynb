# %% [markdown]
# <a href="https://colab.research.google.com/github/MayankDataScience/EDA_1_Data_Science/blob/main/Play_store_app_review_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Play store app review analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Team
# ##### **Team Member 1 -**Mayank Gudadhe
# ##### **Team Member 2 -**Vishal Singh Sangral
# ##### **Team Member 3 -**Kiran Mundhe
# ##### **Team Member 4 -**Amiya Palai
# ##### **Team Member 5 -**Nipu Mishra

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path1='/content/drive/MyDrive/Almabetter Data science/EDA_Projects'

# %%
df1=pd.read_csv(path1 + '/Play Store Data.csv')
df2=pd.read_csv(path1 + '/User Reviews.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df1.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
df2.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print('Total Number of rows in Play Store Data.csv :-',len(df1))
print('Total Number of Columns in Play Store Data.csv :-',len(df1.columns))

print('Total Number of rows in User Reviews.csv :-',len(df2))
print('Total Number of Columns in User Reviews.csv :-',len(df2.columns))
# Out:
# Total Number of rows in Play Store Data.csv :- 10841
# Total Number of Columns in Play Store Data.csv :- 13
# Total Number of rows in User Reviews.csv :- 64295
# Total Number of Columns in User Reviews.csv :- 5

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df1[df1.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df1.isnull().sum()
#df1.notnull()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df1[df1['Rating'].isna()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %%
df1[df1['Type'].isna()]
# Out:
#                             App Category  Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
df1[df1['Android Ver'].isna()]
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#       Reviews    Size Installs  Type     Price Content Rating  \
# 4453      230     11M   1,000+  Paid     $1.49       Everyone
# 4490      189    2.1M  10,000+  Free         0       Everyone
# 10472    3.0M  1,000+     Free     0  Everyone            NaN
#
#                   Genres    Last Updated Current Ver Android Ver
# 4453     Personalization   July 20, 2018         4.4         NaN
# 4490     Personalization  March 27, 2018         1.1         NaN
# 10472  February 11, 2018          1.0.19  4.0 and up         NaN

# %%
df1[df1['Content Rating'].isna()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# Visualizing the missing values
#sns.heatmap(df1.isnull(),yticklabels=False,cbar=False)
plt.figure(figsize=(16,6))
plt.bar(list(df1.columns),list(df1.isnull().sum()))
plt.xlabel('Columns')
plt.ylabel('Null Value')
plt.title('Visualization of Null/Missing value')
plt.show()
# sns.displot(
#     data=df1.isna().melt(value_name="missing"),
#     y="variable",
#     hue="missing",
#     multiple="fill"
# )

# %%
plt.figure(figsize=(16,6))
plt.bar(list(df2.columns),list(df2.isnull().sum()))
plt.xlabel('Columns')
plt.ylabel('Null Value')
plt.title('Visualization of Null/Missing value')
plt.show()
# plt.figure(figsize=(10,6))
# sns.displot(
#     data=df2.isna().melt(value_name="missing"),
#     y="variable",
#     hue="missing",
#     multiple="fill"
# )

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe
df1.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df2.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df1.loc[:].nunique()
# Out:
# App               9660
# Category            34
# Rating              40
# Reviews           6002
# Size               462
# Installs            22
# Type                 3
# Price               93
# Content Rating       6
# Genres             120
# Last Updated      1378
# Current Ver       2832
# Android Ver         33
# dtype: int64

# %%
df1['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df1['Type'].unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %%
df1['App'].unique()
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook',
#        'Coloring book moana',
#        'U Launcher Lite – FREE Live Cool Themes, Hide Apps', ...,
#        'Parkinson Exercices FR', 'The SCP Foundation DB fr nn5n',
#        'iHoroscope - 2018 Daily Horoscope & Astrology'], dtype=object)

# %%
df1['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
df1['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
df1['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df1.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# First we have to change our dtype of Reviews to float 
df1['Reviews'] = pd.to_numeric(df1['Reviews'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "3.0M"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-136dce8b041f> in <module>
#       1 # Write your code to make your dataset analysis ready.
#       2 # First we have to change our dtype of Reviews to float
# ----> 3 df1['Reviews'] = pd.to_numeric(df1['Reviews'])
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
# ...

# %%
#From this error i analyse At the end of this series M is there so we can replace it with empty string
df3=df1['Reviews'].str.replace('M','')

# %%
df3 = pd.to_numeric(df3)
df3.head()
# Out:
# 0       159.0
# 1       967.0
# 2     87510.0
# 3    215644.0
# 4       967.0
# Name: Reviews, dtype: float64

# %%
# Now we confirm that our dtype is changed
df1['Reviews']=df3

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
# Now we have to change our dtype of Installs to float 
df1['Installs']=pd.to_numeric(df1['Installs'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "10,000+"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-c614bca44c50> in <module>
#       1 # Now we have to change our dtype of Installs to float
# ----> 2 df1['Installs']=pd.to_numeric(df1['Installs'])
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ...

# %%
# Now we analyse that + and , cause an error so we can remove that
df4=df1['Installs'].str.replace('+','')

# %%
df1['Installs']=df4

# %%
df4.head()
# Out:
# 0        10,000
# 1       500,000
# 2     5,000,000
# 3    50,000,000
# 4       100,000
# Name: Installs, dtype: object

# %%
df4=df1['Installs'].str.replace(',','')

# %%
df4.head()
# Out:
# 0       10000
# 1      500000
# 2     5000000
# 3    50000000
# 4      100000
# Name: Installs, dtype: object

# %%
#Now again we check to convert into numeric
df4=pd.to_numeric(df4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Free"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-182f8c62d1c4> in <module>
#       1 #Now again we check to convert into numeric
# ----> 2 df4=pd.to_numeric(df4)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ...

# %%
# Now we can replace free
df4=df4.str.replace('Free','')

# %%
df4=pd.to_numeric(df4)

# %%
df1['Installs']=df4

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  object
#  5   Installs        10840 non-null  float64
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 1.1+ MB

# %%
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size    Installs  Type Price Content Rating  \
# 0     159.0   19M     10000.0  Free     0       Everyone
# 1     967.0   14M    500000.0  Free     0       Everyone
# 2   87510.0  8.7M   5000000.0  Free     0       Everyone
# 3  215644.0   25M  50000000.0  Free     0           Teen
# 4     967.0  2.8M    100000.0  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Same process for Price
df1['Price']=pd.to_numeric(df1['Price'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "$4.99"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-2d5045f01bbc> in <module>
#       1 # Same process for Price
# ----> 2 df1['Price']=pd.to_numeric(df1['Price'])
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ...

# %%
# first we remove dollar
df5=df1['Price'].str.replace('$','')
# Out:
# <ipython-input-84-10af2bb5b51e>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df5=df1['Price'].str.replace('$','')

# %%
df5=pd.to_numeric(df5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Everyone"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-e9d6e6daeb66> in <module>
# ----> 1 df5=pd.to_numeric(df5)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ...

# %%
df1['Price']=df5

# %%
df5=df5.str.replace('Everyone','')

# %%
df5=pd.to_numeric(df5)

# %%
df1['Price']=df5

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  object
#  5   Installs        10840 non-null  float64
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 1.1+ MB

# %%
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size    Installs  Type  Price Content Rating  \
# 0     159.0   19M     10000.0  Free    0.0       Everyone
# 1     967.0   14M    500000.0  Free    0.0       Everyone
# 2   87510.0  8.7M   5000000.0  Free    0.0       Everyone
# 3  215644.0   25M  50000000.0  Free    0.0           Teen
# 4     967.0  2.8M    100000.0  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df1['Size']=pd.to_numeric(df1['Size'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "19M"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-dcc8c6849073> in <module>
# ----> 1 df1['Size']=pd.to_numeric(df1['Size'])
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ...

# %%
df6=df1['Size'].str.replace('M','')

# %%
df6=pd.to_numeric(df6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Varies with device"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-f29ccfb6add5> in <module>
# ----> 1 df6=pd.to_numeric(df6)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ...

# %%
df1.sample(50)
# Out:
#                                                      App             Category  \
# 8614                                   Sweden Newspapers   NEWS_AND_MAGAZINES
# 1907                                          Bowmasters                 GAME
# 3565                                        Google Drive         PRODUCTIVITY
# 2841                       Photo Collage - Layout Editor          PHOTOGRAPHY
# 9980                                     EvAk Smart Home            LIFESTYLE
# 7778               Chest Opener for CR - The Circle Game               FAMILY
# 4967                          Ez Screen Recorder (no ad)        VIDEO_PLAYERS
# 3469                       ES File Explorer File Manager         PRODUCTIVITY
# 4300   PowerDirector Video Editor App: 4K, Slow Mo & ...        VIDEO_PLAYERS
# 10041                            Advanced EX for HYUNDAI                TOOLS
# 10095                                 Pink Guy - Ey B0ss               FAMILY
# ...

# %%
df1[(df1['Size']=='Varies with device')]
# Out:
#                                                      App             Category  \
# 37                                    Floor Plan Creator       ART_AND_DESIGN
# 42                            Textgram - write on photos       ART_AND_DESIGN
# 52                         Used Cars and Trucks for Sale    AUTO_AND_VEHICLES
# 67                                    Ulysse Speedometer    AUTO_AND_VEHICLES
# 68                                                REPUVE    AUTO_AND_VEHICLES
# ...                                                  ...                  ...
# 10713  My Earthquake Alerts - US & Worldwide Earthquakes              WEATHER
# 10725                                          Posta App  MAPS_AND_NAVIGATION
# 10765                    Chat For Strangers - Video Chat               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
# ...

# %%
df6=df6.str.replace('Varies with device','5')

# %%
df6=pd.to_numeric(df6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "201k"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-f29ccfb6add5> in <module>
# ----> 1 df6=pd.to_numeric(df6)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ...

# %%
# df1[(df1['Size']==[0-9*k$])]
a=df1['Size'].str.endswith('k')

# %%
# We check how many apps are free 
df1[(df1['Type']=='Free')]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# We check how many apps are Paid
df1[(df1['Type']=='Paid')]
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 290    TurboScan: scan documents and receipts in PDF            BUSINESS
# 291                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# ...                                              ...                 ...
# 10735                                    FP VoiceBot              FAMILY
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
# 10798                           Word Search Tab 1 FR              FAMILY
#
#        Rating  Reviews                Size  Installs  Type  Price  \
# ...

# %%
df1[(df1['Type'].isna())]
# Out:
#                             App Category  Rating  Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN      0.0  Varies with device
#
#       Installs Type  Price Content Rating    Genres   Last Updated  \
# 9148       0.0  NaN    0.0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  object
#  5   Installs        10840 non-null  float64
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 1.1+ MB

# %%
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size    Installs  Type  Price Content Rating  \
# 0     159.0   19M     10000.0  Free    0.0       Everyone
# 1     967.0   14M    500000.0  Free    0.0       Everyone
# 2   87510.0  8.7M   5000000.0  Free    0.0       Everyone
# 3  215644.0   25M  50000000.0  Free    0.0           Teen
# 4     967.0  2.8M    100000.0  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
Genres=df1.groupby('Genres')

# %%
Genres.size().sort_values(ascending=False)
# Out:
# Genres
# Tools                           842
# Entertainment                   623
# Education                       549
# Medical                         463
# Business                        460
#                                ...
# Puzzle;Education                  1
# Books & Reference;Creativity      1
# Role Playing;Education            1
# Role Playing;Brain Games          1
# February 11, 2018                 1
# Length: 120, dtype: int64

# %%
Genres.first()
# Out:
#                                                                                      App  \
# Genres
# Action                                                                        slither.io
# Action;Action & Adventure                                 Strawberry Shortcake BerryRush
# Adventure                                                                     Pokémon GO
# Adventure;Action & Adventure                                                      ROBLOX
# Adventure;Brain Games                                     The Hunt for the Lost Treasure
# ...                                                                                  ...
# Video Players & Editors                                                          YouTube
# Video Players & Editors;Creativity                                          Video Editor
# Video Players & Editors;Music & Video                                Cartoon Network App
# ...

# %%
Genres.get_group('Action')
# Out:
#                                                 App Category  Rating  \
# 1659                                     slither.io     GAME     4.4
# 1661                                   Temple Run 2     GAME     4.3
# 1663                                     Helix Jump     GAME     4.2
# 1669                             Zombie Hunter King     GAME     4.3
# 1671                                 Kick the Buddy     GAME     4.3
# ...                                             ...      ...     ...
# 10783  Modern Counter Terror Attack – Shooting Game     GAME     4.2
# 10784                                    Big Hunter     GAME     4.3
# 10787               Modern Counter Global Strike 3D     GAME     4.1
# 10789            Modern Counter Global Strike 3D V2     GAME     4.0
# 10803                  Fatal Raid - No.1 Mobile FPS     GAME     4.3
#
#          Reviews                Size     Installs  Type  Price Content Rating  \
# ...

# %%
Category=df1.groupby('Category')

# %%
Category.size().sort_values(ascending=False)
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
Category.first()
# Out:
#                                                                    App  \
# Category
# 1.9                            Life Made WI-Fi Touchscreen Photo Frame
# ART_AND_DESIGN          Photo Editor & Candy Camera & Grid & ScrapBook
# AUTO_AND_VEHICLES                          Monster Truck Stunt 3D 2019
# BEAUTY                                      Hush - Beauty for Everyone
# BOOKS_AND_REFERENCE                               Wattpad 📖 Free Books
# BUSINESS                                  Visual Voicemail by MetroPCS
# COMICS                                      LINE WEBTOON - Free Comics
# COMMUNICATION                 Messenger – Text and Video Chat for Free
# DATING                                       Moco+ - Chat, Meet People
# EDUCATION                               Duolingo: Learn Languages Free
# ENTERTAINMENT                                                  Netflix
# EVENTS                                              All Events in City
# ...

# %%
Category.get_group('FAMILY')
# Out:
#                                     App Category  Rating    Reviews  \
# 2014                       YouTube Kids   FAMILY     4.5   470694.0
# 2015                         Candy Bomb   FAMILY     4.4    42145.0
# 2016                             ROBLOX   FAMILY     4.5  4449910.0
# 2017       Jewels Crush- Match 3 Puzzle   FAMILY     4.4    14774.0
# 2018                   Coloring & Learn   FAMILY     4.4    12753.0
# ...                                 ...      ...     ...        ...
# 10821                           Poop FR   FAMILY     NaN        6.0
# 10827                Fr Agnel Ambarnath   FAMILY     4.2      117.0
# 10834                     FR Calculator   FAMILY     4.0        7.0
# 10836                  Sya9a Maroc - FR   FAMILY     4.5       38.0
# 10837  Fr. Mike Schmitz Audio Teachings   FAMILY     5.0        4.0
#
#                      Size     Installs  Type  Price Content Rating  \
# 2014   Varies with device   50000000.0  Free    0.0       Everyone
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  object
#  5   Installs        10840 non-null  float64
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 1.1+ MB

# %%
df1.describe()
# Out:
#             Rating       Reviews      Installs         Price
# count  9367.000000  1.084100e+04  1.084000e+04  10840.000000
# mean      4.193338  4.441119e+05  1.546434e+07      1.027368
# std       0.537431  2.927629e+06  8.502936e+07     15.949703
# min       1.000000  0.000000e+00  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03  1.000000e+05      0.000000
# 75%       4.500000  5.476800e+04  5.000000e+06      0.000000
# max      19.000000  7.815831e+07  1.000000e+09    400.000000

# %%
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size    Installs  Type  Price Content Rating  \
# 0     159.0   19M     10000.0  Free    0.0       Everyone
# 1     967.0   14M    500000.0  Free    0.0       Everyone
# 2   87510.0  8.7M   5000000.0  Free    0.0       Everyone
# 3  215644.0   25M  50000000.0  Free    0.0           Teen
# 4     967.0  2.8M    100000.0  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             1
# Type                 1
# Price                1
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
mean_value_rating=df1['Rating'].mean()

# %%
mean_value_rating=round(mean_value_rating,1)

# %%
mean_value_rating
# Out:
# 4.2

# %%
df1['Rating'].fillna(value=mean_value_rating, inplace=True)

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          1
# Type              1
# Price             1
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %%
df1[df1['Price'].isna()]
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0      3.0
#
#          Size  Installs Type  Price Content Rating             Genres  \
# 10472  1,000+       NaN    0    NaN            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df1.drop(10472,axis=0,inplace=True)

# %%
df1[df1['Price'].isna()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df1[df1['Installs'].isna()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
df1[df1['Type'].isna()]
# Out:
#                             App Category  Rating  Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     4.2      0.0  Varies with device
#
#       Installs Type  Price Content Rating    Genres   Last Updated  \
# 9148       0.0  NaN    0.0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
df1.drop(9148,axis=0,inplace=True)

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
df1[df1['Android Ver'].isna()]
# Out:
#                          App         Category  Rating  Reviews  Size  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4    230.0   11M
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5    189.0  2.1M
#
#       Installs  Type  Price Content Rating           Genres    Last Updated  \
# 4453    1000.0  Paid   1.49       Everyone  Personalization   July 20, 2018
# 4490   10000.0  Free   0.00       Everyone  Personalization  March 27, 2018
#
#      Current Ver Android Ver
# 4453         4.4         NaN
# 4490         1.1         NaN

# %%
df1[df1['Current Ver'].isna()]
# Out:
#                                    App             Category  Rating  Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2     55.0
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1  20145.0
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2   4010.0
# 6803                         BT Master               FAMILY     4.2      0.0
# 7333                       Dots puzzle               FAMILY     4.0    179.0
# 7407                   Calculate My IQ               FAMILY     4.2     44.0
# 7730                            UFO-CQ                TOOLS     4.2      1.0
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     4.2      8.0
#
#        Size   Installs  Type  Price Content Rating             Genres  \
# 15     2.7M     5000.0  Free   0.00       Everyone       Art & Design
# 1553    11k  1000000.0  Free   0.00       Everyone   Libraries & Demo
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10839 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          10839 non-null  float64
#  3   Reviews         10839 non-null  float64
#  4   Size            10839 non-null  object
#  5   Installs        10839 non-null  float64
#  6   Type            10839 non-null  object
#  7   Price           10839 non-null  float64
#  8   Content Rating  10839 non-null  object
#  9   Genres          10839 non-null  object
#  10  Last Updated    10839 non-null  object
#  11  Current Ver     10831 non-null  object
#  12  Android Ver     10837 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 1.2+ MB

# %%
plt.figure(figsize=(16,6))
plt.bar(list(df1.columns),list(df1.isnull().sum()))
plt.xlabel('Columns')
plt.ylabel('Null Value')
plt.title('Visualization of Null/Missing value')
plt.show()

# %%
df1.dropna().shape
#10829 Rows has not any null value
# Out:
# (10829, 13)

# %%
df1.dropna(how='all').shape
#It is clear that we dont have any Row which has totally empty
# Out:
# (10839, 13)

# %%
df1.dropna(subset=['Current Ver']).shape
# Out:
# (10831, 13)

# %%
df1.dropna(subset=['Current Ver'],inplace=True)

# %%
df1.dropna(subset=['Android Ver']).shape
# Out:
# (10829, 13)

# %%
df1[df1['Android Ver'].isna()]
# Out:
#                          App         Category  Rating  Reviews  Size  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4    230.0   11M
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5    189.0  2.1M
#
#       Installs  Type  Price Content Rating           Genres    Last Updated  \
# 4453    1000.0  Paid   1.49       Everyone  Personalization   July 20, 2018
# 4490   10000.0  Free   0.00       Everyone  Personalization  March 27, 2018
#
#      Current Ver Android Ver
# 4453         4.4         NaN
# 4490         1.1         NaN

# %%
df1.dropna(subset=['Android Ver'],inplace=True)

# %%
df1[df1['Android Ver'].isna()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10829 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10829 non-null  object
#  1   Category        10829 non-null  object
#  2   Rating          10829 non-null  float64
#  3   Reviews         10829 non-null  float64
#  4   Size            10829 non-null  object
#  5   Installs        10829 non-null  float64
#  6   Type            10829 non-null  object
#  7   Price           10829 non-null  float64
#  8   Content Rating  10829 non-null  object
#  9   Genres          10829 non-null  object
#  10  Last Updated    10829 non-null  object
#  11  Current Ver     10829 non-null  object
#  12  Android Ver     10829 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 1.2+ MB

# %%
df1['Last Updated']= pd.to_datetime(df1['Last Updated'])
# We convert Last updated coloum which is needed to have in datetime dtype but it is in object to we convert this

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10829 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10829 non-null  object
#  1   Category        10829 non-null  object
#  2   Rating          10829 non-null  float64
#  3   Reviews         10829 non-null  float64
#  4   Size            10829 non-null  object
#  5   Installs        10829 non-null  float64
#  6   Type            10829 non-null  object
#  7   Price           10829 non-null  float64
#  8   Content Rating  10829 non-null  object
#  9   Genres          10829 non-null  object
#  10  Last Updated    10829 non-null  datetime64[ns]
#  11  Current Ver     10829 non-null  object
#  12  Android Ver     10829 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(8)
# memory usage: 1.2+ MB

# %%
df1.sample(50)
# Out:
#                                                      App             Category  \
# 1715                                         Word Search                 GAME
# 3066    Yahoo Sports - scores, stats, news, & highlights               SPORTS
# 506                                                Howlr               DATING
# 2851                      Beauty Makeup – Photo Makeover          PHOTOGRAPHY
# 6114                                            Bf Light             BUSINESS
# 2854                      Muzy - Share photos & collages          PHOTOGRAPHY
# 9892                             Have your say on Europe        COMMUNICATION
# 4220                                               Helix                 GAME
# 10358                           Theme For Galaxy Note FE      PERSONALIZATION
# 782                                         Khan Academy            EDUCATION
# 4927                       All Type Ac Repair & Services            LIFESTYLE
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10829 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10829 non-null  object
#  1   Category        10829 non-null  object
#  2   Rating          10829 non-null  float64
#  3   Reviews         10829 non-null  float64
#  4   Size            10829 non-null  object
#  5   Installs        10829 non-null  float64
#  6   Type            10829 non-null  object
#  7   Price           10829 non-null  float64
#  8   Content Rating  10829 non-null  object
#  9   Genres          10829 non-null  object
#  10  Last Updated    10829 non-null  datetime64[ns]
#  11  Current Ver     10829 non-null  object
#  12  Android Ver     10829 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(8)
# memory usage: 1.2+ MB

# %%
for i in df1.index:
  a=df1.loc[i,'Size']
  if a.endswith('k'):
    a=a.replace('k','')
    a=float(a)
    a= a/1048576
    a=str(a)
    a=a+'M'
  df1.loc[i,'Size']=a

# %%
df1.sample(50)
# Out:
#                                                      App             Category  \
# 3409                      icon wallpaper dressup💞CocoPPa      PERSONALIZATION
# 2510                            Blood Pressure(BP) Diary              MEDICAL
# 1246                                           Pizza Hut       FOOD_AND_DRINK
# 8042                                    Cx File Explorer                TOOLS
# 8483                       10 Minutes a Day Times Tables               FAMILY
# 2377                         Johns Hopkins Guides ABX...              MEDICAL
# 2645                                               LOVOO               SOCIAL
# 6172         Bg Radios - Bulgarian radio stations online               FAMILY
# 174                     English translation from Bengali  BOOKS_AND_REFERENCE
# 454    myMail – Email for Hotmail, Gmail and Outlook ...        COMMUNICATION
# 595                        WannaMeet – Dating & Chat App               DATING
# ...

# %%
df1[(df1['Size']=='Varies with device')]
# Out:
#                                                      App             Category  \
# 37                                    Floor Plan Creator       ART_AND_DESIGN
# 42                            Textgram - write on photos       ART_AND_DESIGN
# 52                         Used Cars and Trucks for Sale    AUTO_AND_VEHICLES
# 67                                    Ulysse Speedometer    AUTO_AND_VEHICLES
# 68                                                REPUVE    AUTO_AND_VEHICLES
# ...                                                  ...                  ...
# 10713  My Earthquake Alerts - US & Worldwide Earthquakes              WEATHER
# 10725                                          Posta App  MAPS_AND_NAVIGATION
# 10765                    Chat For Strangers - Video Chat               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
# ...

# %%
df1.dropna(subset=['Size']).shape
# Out:
# (10829, 13)

# %%
df1.dropna(how='all',subset=['Size']).shape
# Out:
# (10829, 13)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10829 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10829 non-null  object
#  1   Category        10829 non-null  object
#  2   Rating          10829 non-null  float64
#  3   Reviews         10829 non-null  float64
#  4   Size            10829 non-null  object
#  5   Installs        10829 non-null  float64
#  6   Type            10829 non-null  object
#  7   Price           10829 non-null  float64
#  8   Content Rating  10829 non-null  object
#  9   Genres          10829 non-null  object
#  10  Last Updated    10829 non-null  datetime64[ns]
#  11  Current Ver     10829 non-null  object
#  12  Android Ver     10829 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(8)
# memory usage: 1.4+ MB

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df1.to_csv('/content/drive/MyDrive/Almabetter Data science/Data/playstore.csv', encoding='utf-8', index=False)

# %%
# Now we can make our second Dataset analysis ready
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
df2.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***

# %%
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10000.0  Free     0       Everyone
# 1     967   14M    500000.0  Free     0       Everyone
# 2   87510  8.7M   5000000.0  Free     0       Everyone
# 3  215644   25M  50000000.0  Free     0           Teen
# 4     967  2.8M    100000.0  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...
